# %%
import pandas as pd
import numpy as np
import json

# %%
path = '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/splits.json'

# %%
data = json.load(open(path, 'r'))['train']
data
# Out:
# ['0_0001',
#  '0_0002',
#  '0_0003',
#  '0_0005',
#  '0_0006',
#  '0_0007',
#  '0_0009',
#  '0_0010',
#  '0_0011',
#  '0_0013',
#  '0_0014',
#  '0_0015',
#  '0_0017',
#  '0_0018',
#  '0_0019',
#  '0_0021',
#  '0_0022',
#  '0_0023',
#  '0_0025',
#  '0_0026',
#  '0_0027',
#  '0_0029',
#  '0_0030',
#  '0_0031',
#  '0_0033',
#  '0_0034',
#  '0_0035',
#  '0_0037',
#  '0_0038',
#  '0_0039',
#  '0_0041',
#  '0_0042',
#  '0_0043',
#  '0_0045',
#  '0_0046',
#  '0_0047',
#  '0_0049',
#  '0_0050',
#  '0_0051',
#  '0_0053',
#  '0_0054',
#  '0_0055',
#  '0_0057',
#  '0_0058',
#  '0_0059',
#  '0_0061',
#  '0_0062',
#  '0_0063',
#  '0_0065',
#  '0_0066',
#  '0_0067',
#  '0_0069',
#  '0_0070',
#  '0_0071',
#  '0_0073',
#  '0_0074',
#  '0_0075',
#  '0_0077',
#  '0_0078',
#  '0_0079',
#  '0_0081',
#  '0_0082',
#  '0_0083',
#  '0_0085',
#  '0_0086',
#  '0_0087',
#  '0_0089',
#  '0_0090',
#  '0_0091',
#  '0_0093',
#  '0_0094',
#  '0_0095',
#  '0_0097',
#  '0_0098',
#  '0_0099',
#  '0_0101',
#  '0_0102',
#  '0_0103',
#  '0_0105',
#  '0_0106',
#  '0_0107',
#  '0_0109',
#  '0_0110',
#  '0_0111',
#  '0_0113',
#  '0_0114',
#  '0_0115',
#  '0_0117',
#  '0_0118',
#  '0_0119',
#  '0_0121',
#  '0_0122',
#  '0_0123',
#  '0_0125',
#  '0_0126',
#  '0_0127',
#  '0_0129',
#  '0_0130',
#  '0_0131',
#  '0_0133',
#  '0_0134',
#  '0_0135',
#  '0_0137',
#  '0_0138',
#  '0_0139',
#  '0_0141',
#  '0_0142',
#  '0_0143',
#  '0_0145',
#  '0_0146',
#  '0_0147',
#  '0_0149',
#  '0_0150',
#  '0_0151',
#  '0_0153',
#  '0_0154',
#  '0_0155',
#  '0_0157',
#  '0_0158',
#  '0_0159',
#  '0_0161',
#  '0_0162',
#  '0_0163',
#  '0_0165',
#  '0_0166',
#  '0_0167',
#  '0_0169',
#  '0_0170',
#  '0_0171',
#  '0_0173',
#  '0_0174',
#  '0_0175',
#  '0_0177',
#  '0_0178',
#  '0_0179',
#  '0_0181',
#  '0_0182',
#  '0_0183',
#  '0_0185',
#  '0_0186',
#  '0_0187',
#  '0_0189',
#  '0_0190',
#  '0_0191',
#  '0_0193',
#  '0_0194',
#  '0_0195',
#  '0_0197',
#  '0_0198',
#  '0_0199',
#  '0_0201',
#  '0_0202',
#  '0_0203',
#  '0_0205',
#  '0_0206',
#  '0_0207',
#  '0_0209',
#  '0_0210',
#  '0_0211',
#  '0_0213',
#  '0_0214',
#  '0_0215',
#  '0_0217',
#  '0_0218',
#  '0_0219',
#  '0_0221',
#  '0_0222',
#  '0_0223',
#  '0_0225',
#  '0_0226',
#  '0_0227',
#  '0_0229',
#  '0_0230',
#  '0_0231',
#  '0_0233',
#  '0_0234',
#  '0_0235',
#  '0_0237',
#  '0_0238',
#  '0_0239',
#  '0_0241',
#  '0_0242',
#  '0_0243',
#  '0_0245',
#  '0_0246',
#  '0_0247',
#  '0_0249',
#  '0_0250',
#  '0_0251',
#  '0_0253',
#  '0_0254',
#  '0_0255',
#  '0_0257',
#  '0_0258',
#  '0_0259',
#  '0_0261',
#  '0_0262',
#  '0_0263',
#  '0_0265',
#  '0_0266',
#  '0_0267',
#  '0_0269',
#  '0_0270',
#  '0_0271',
#  '0_0273',
#  '0_0274',
#  '0_0275',
#  '0_0277',
#  '0_0278',
#  '0_0279',
#  '0_0281',
#  '0_0282',
#  '0_0283',
#  '0_0285',
#  '0_0286',
#  '0_0287',
#  '0_0289',
#  '0_0290',
#  '0_0291',
#  '0_0293',
#  '0_0294',
#  '0_0295',
#  '0_0297',
#  '0_0298',
#  '0_0299',
#  '0_0301',
#  '0_0302',
#  '0_0303',
#  '0_0305',
#  '0_0306',
#  '0_0307',
#  '0_0309',
#  '0_0310',
#  '0_0311',
#  '0_0313',
#  '0_0314',
#  '0_0315',
#  '0_0317',
#  '0_0318',
#  '0_0319',
#  '0_0321',
#  '0_0322',
#  '0_0323',
#  '0_0325',
#  '0_0326',
#  '0_0327',
#  '0_0329',
#  '0_0330',
#  '0_0331',
#  '0_0333',
#  '0_0334',
#  '0_0335',
#  '0_0337',
#  '0_0338',
#  '0_0339',
#  '0_0341',
#  '0_0342',
#  '0_0343',
#  '0_0345',
#  '0_0346',
#  '0_0347',
#  '0_0349',
#  '0_0350',
#  '0_0351',
#  '0_0353',
#  '0_0354',
#  '0_0355',
#  '0_0357',
#  '0_0358',
#  '0_0359',
#  '0_0361',
#  '0_0362',
#  '0_0363',
#  '0_0365',
#  '0_0366',
#  '0_0367',
#  '0_0369',
#  '0_0370',
#  '0_0371',
#  '0_0373',
#  '0_0374',
#  '0_0375',
#  '0_0377',
#  '0_0378',
#  '0_0379',
#  '0_0381',
#  '0_0382',
#  '0_0383',
#  '0_0385',
#  '0_0386',
#  '0_0387',
#  '0_0389',
#  '0_0390',
#  '0_0391',
#  '0_0393',
#  '0_0394',
#  '0_0395',
#  '0_0397',
#  '0_0398',
#  '0_0399',
#  '0_0401',
#  '0_0402',
#  '0_0403',
#  '0_0405',
#  '0_0406',
#  '0_0407',
#  '0_0409',
#  '0_0410',
#  '0_0411',
#  '0_0413',
#  '0_0414',
#  '0_0415',
#  '0_0417',
#  '0_0418',
#  '0_0419',
#  '0_0421',
#  '0_0422',
#  '0_0423',
#  '0_0425',
#  '0_0426',
#  '0_0427',
#  '0_0429',
#  '0_0430',
#  '0_0431',
#  '0_0433',
#  '0_0434',
#  '0_0435',
#  '0_0437',
#  '0_0438',
#  '0_0439',
#  '0_0441',
#  '0_0442',
#  '0_0443',
#  '0_0445',
#  '0_0446',
#  '0_0447',
#  '0_0449',
#  '0_0450',
#  '0_0451',
#  '0_0453',
#  '0_0454',
#  '0_0455',
#  '0_0457',
#  '0_0458',
#  '0_0459',
#  '0_0461',
#  '0_0462',
#  '0_0463',
#  '0_0465',
#  '0_0466',
#  '0_0467',
#  '0_0469',
#  '0_0470',
#  '0_0471',
#  '0_0473',
#  '0_0474',
#  '0_0475',
#  '0_0477',
#  '0_0478',
#  '0_0479',
#  '0_0481',
#  '0_0482',
#  '0_0483',
#  '0_0485',
#  '0_0486',
#  '0_0487',
#  '0_0489',
#  '0_0490',
#  '0_0491',
#  '0_0493',
#  '0_0494',
#  '0_0495',
#  '0_0497',
#  '0_0498',
#  '0_0499',
#  '0_0501',
#  '0_0502',
#  '0_0503',
#  '0_0505',
#  '0_0506',
#  '0_0507',
#  '0_0509',
#  '0_0510',
#  '0_0511',
#  '0_0513',
#  '0_0514',
#  '0_0515',
#  '0_0517',
#  '0_0518',
#  '0_0519',
#  '0_0521',
#  '0_0522',
#  '0_0523',
#  '0_0525',
#  '0_0526',
#  '0_0527',
#  '0_0529',
#  '0_0530',
#  '0_0531',
#  '0_0533',
#  '0_0534',
#  '0_0535',
#  '0_0537',
#  '0_0538',
#  '0_0539',
#  '0_0541',
#  '0_0542',
#  '0_0543',
#  '0_0545',
#  '0_0546',
#  '0_0547',
#  '0_0549',
#  '0_0550',
#  '0_0551',
#  '0_0553',
#  '0_0554',
#  '0_0555',
#  '0_0557',
#  '0_0558',
#  '0_0559',
#  '0_0561',
#  '0_0562',
#  '0_0563',
#  '0_0565',
#  '0_0566',
#  '0_0567',
#  '0_0569',
#  '0_0570',
#  '0_0571',
#  '0_0573',
#  '0_0574',
#  '0_0575',
#  '0_0577',
#  '0_0578',
#  '0_0579',
#  '0_0581',
#  '0_0582',
#  '0_0583',
#  '0_0585',
#  '0_0586',
#  '0_0587',
#  '0_0589',
#  '0_0590',
#  '0_0591',
#  '0_0593',
#  '0_0594',
#  '0_0595',
#  '0_0597',
#  '0_0598',
#  '0_0599',
#  '0_0601',
#  '0_0602',
#  '0_0603',
#  '0_0605',
#  '0_0606',
#  '0_0607',
#  '0_0609',
#  '0_0610',
#  '0_0611',
#  '0_0613',
#  '0_0614',
#  '0_0615',
#  '0_0617',
#  '0_0618',
#  '0_0619',
#  '0_0621',
#  '0_0622',
#  '0_0623',
#  '0_0625',
#  '0_0626',
#  '0_0627',
#  '0_0629',
#  '0_0630',
#  '0_0631',
#  '0_0633',
#  '0_0634',
#  '0_0635',
#  '0_0637',
#  '0_0638',
#  '0_0639',
#  '0_0641',
#  '0_0642',
#  '0_0643',
#  '0_0645',
#  '0_0646',
#  '0_0647',
#  '0_0649',
#  '0_0650',
#  '0_0651',
#  '0_0653',
#  '0_0654',
#  '0_0655',
#  '0_0657',
#  '0_0658',
#  '0_0659',
#  '0_0661',
#  '0_0662',
#  '0_0663',
#  '0_0665',
#  '0_0666',
#  '0_0667',
#  '0_0669',
#  '0_0670',
#  '0_0671',
#  '0_0673',
#  '0_0674',
#  '0_0675',
#  '0_0677',
#  '0_0678',
#  '0_0679',
#  '0_0681',
#  '0_0682',
#  '0_0683',
#  '0_0685',
#  '0_0686',
#  '0_0687',
#  '0_0689',
#  '0_0690',
#  '0_0691',
#  '0_0693',
#  '0_0694',
#  '0_0695',
#  '0_0697',
#  '0_0698',
#  '0_0699',
#  '0_0701',
#  '0_0702',
#  '0_0703',
#  '0_0705',
#  '0_0706',
#  '0_0707',
#  '0_0709',
#  '0_0710',
#  '0_0711',
#  '0_0713',
#  '0_0714',
#  '0_0715',
#  '0_0717',
#  '0_0718',
#  '0_0719',
#  '0_0721',
#  '0_0722',
#  '0_0723',
#  '0_0725',
#  '0_0726',
#  '0_0727',
#  '0_0729',
#  '0_0730',
#  '0_0731',
#  '0_0733',
#  '0_0734',
#  '0_0735',
#  '0_0737',
#  '0_0738',
#  '0_0739',
#  '0_0741',
#  '0_0742',
#  '0_0743',
#  '0_0745',
#  '0_0746',
#  '0_0747',
#  '0_0749',
#  '0_0750',
#  '0_0751',
#  '0_0753',
#  '0_0754',
#  '0_0755',
#  '0_0757',
#  '0_0758',
#  '0_0759',
#  '0_0761',
#  '0_0762',
#  '0_0763',
#  '0_0765',
#  '0_0766',
#  '0_0767',
#  '0_0769',
#  '0_0770',
#  '0_0771',
#  '0_0773',
#  '0_0774',
#  '0_0775',
#  '0_0777',
#  '0_0778',
#  '0_0779',
#  '0_0781',
#  '0_0782',
#  '0_0783',
#  '0_0785',
#  '0_0786',
#  '0_0787',
#  '0_0789',
#  '0_0790',
#  '0_0791',
#  '0_0793',
#  '0_0794',
#  '0_0795',
#  '0_0797',
#  '0_0798',
#  '0_0799',
#  '0_0801',
#  '0_0802',
#  '0_0803',
#  '0_0805',
#  '0_0806',
#  '0_0807',
#  '0_0809',
#  '0_0810',
#  '0_0811',
#  '0_0813',
#  '0_0814',
#  '0_0815',
#  '0_0817',
#  '0_0818',
#  '0_0819',
#  '0_0821',
#  '0_0822',
#  '0_0823',
#  '0_0825',
#  '0_0826',
#  '0_0827',
#  '0_0829',
#  '0_0830',
#  '0_0831',
#  '0_0833',
#  '0_0834',
#  '0_0835',
#  '0_0837',
#  '0_0838',
#  '0_0839',
#  '0_0841',
#  '0_0842',
#  '0_0843',
#  '0_0845',
#  '0_0846',
#  '0_0847',
#  '0_0849',
#  '0_0850',
#  '0_0851',
#  '0_0853',
#  '0_0854',
#  '0_0855',
#  '0_0857',
#  '0_0858',
#  '0_0859',
#  '0_0861',
#  '0_0862',
#  '0_0863',
#  '0_0865',
#  '0_0866',
#  '0_0867',
#  '0_0869',
#  '0_0870',
#  '0_0871',
#  '0_0873',
#  '0_0874',
#  '0_0875',
#  '0_0877',
#  '0_0878',
#  '0_0879',
#  '0_0881',
#  '0_0882',
#  '0_0883',
#  '0_0885',
#  '0_0886',
#  '0_0887',
#  '0_0889',
#  '0_0890',
#  '0_0891',
#  '0_0893',
#  '0_0894',
#  '0_0895',
#  '0_0897',
#  '0_0898',
#  '0_0899']

# %%
def convert_image_name(image_name):
    # Split the image name at the underscore
    prefix, number = image_name.split('_')
    
    # Pad the number with one additional zero
    padded_number = f'{int(number):05d}'  # Ensures the number has 5 digits
    
    # Create the new image names
    frame_name = f'frame_{padded_number}'
    depth_name = f'depth_{padded_number}'
    
    return frame_name, depth_name

# Example usage
original_name = '0_0001'
frame_name, depth_name = convert_image_name(original_name)

print('Frame:', frame_name)
print('Depth:', depth_name)
# Out:
# Frame: frame_00001
# Depth: depth_00001

# %%
frames, depths = [], []
for d in data:
    frame_name, depth_name = convert_image_name(d)
    frames.append(frame_name+'.png')
    depths.append(depth_name+'.png')

print(frames[-5:])
print(depths[-5:])
# Out:
# ['frame_00894.png', 'frame_00895.png', 'frame_00897.png', 'frame_00898.png', 'frame_00899.png']
# ['depth_00894.png', 'depth_00895.png', 'depth_00897.png', 'depth_00898.png', 'depth_00899.png']

# %% [markdown]
# ## move test images out of results folder

# %%
depths
# Out:
# ['depth_00001.png',
#  'depth_00002.png',
#  'depth_00003.png',
#  'depth_00005.png',
#  'depth_00006.png',
#  'depth_00007.png',
#  'depth_00009.png',
#  'depth_00010.png',
#  'depth_00011.png',
#  'depth_00013.png',
#  'depth_00014.png',
#  'depth_00015.png',
#  'depth_00017.png',
#  'depth_00018.png',
#  'depth_00019.png',
#  'depth_00021.png',
#  'depth_00022.png',
#  'depth_00023.png',
#  'depth_00025.png',
#  'depth_00026.png',
#  'depth_00027.png',
#  'depth_00029.png',
#  'depth_00030.png',
#  'depth_00031.png',
#  'depth_00033.png',
#  'depth_00034.png',
#  'depth_00035.png',
#  'depth_00037.png',
#  'depth_00038.png',
#  'depth_00039.png',
#  'depth_00041.png',
#  'depth_00042.png',
#  'depth_00043.png',
#  'depth_00045.png',
#  'depth_00046.png',
#  'depth_00047.png',
#  'depth_00049.png',
#  'depth_00050.png',
#  'depth_00051.png',
#  'depth_00053.png',
#  'depth_00054.png',
#  'depth_00055.png',
#  'depth_00057.png',
#  'depth_00058.png',
#  'depth_00059.png',
#  'depth_00061.png',
#  'depth_00062.png',
#  'depth_00063.png',
#  'depth_00065.png',
#  'depth_00066.png',
#  'depth_00067.png',
#  'depth_00069.png',
#  'depth_00070.png',
#  'depth_00071.png',
#  'depth_00073.png',
#  'depth_00074.png',
#  'depth_00075.png',
#  'depth_00077.png',
#  'depth_00078.png',
#  'depth_00079.png',
#  'depth_00081.png',
#  'depth_00082.png',
#  'depth_00083.png',
#  'depth_00085.png',
#  'depth_00086.png',
#  'depth_00087.png',
#  'depth_00089.png',
#  'depth_00090.png',
#  'depth_00091.png',
#  'depth_00093.png',
#  'depth_00094.png',
#  'depth_00095.png',
#  'depth_00097.png',
#  'depth_00098.png',
#  'depth_00099.png',
#  'depth_00101.png',
#  'depth_00102.png',
#  'depth_00103.png',
#  'depth_00105.png',
#  'depth_00106.png',
#  'depth_00107.png',
#  'depth_00109.png',
#  'depth_00110.png',
#  'depth_00111.png',
#  'depth_00113.png',
#  'depth_00114.png',
#  'depth_00115.png',
#  'depth_00117.png',
#  'depth_00118.png',
#  'depth_00119.png',
#  'depth_00121.png',
#  'depth_00122.png',
#  'depth_00123.png',
#  'depth_00125.png',
#  'depth_00126.png',
#  'depth_00127.png',
#  'depth_00129.png',
#  'depth_00130.png',
#  'depth_00131.png',
#  'depth_00133.png',
#  'depth_00134.png',
#  'depth_00135.png',
#  'depth_00137.png',
#  'depth_00138.png',
#  'depth_00139.png',
#  'depth_00141.png',
#  'depth_00142.png',
#  'depth_00143.png',
#  'depth_00145.png',
#  'depth_00146.png',
#  'depth_00147.png',
#  'depth_00149.png',
#  'depth_00150.png',
#  'depth_00151.png',
#  'depth_00153.png',
#  'depth_00154.png',
#  'depth_00155.png',
#  'depth_00157.png',
#  'depth_00158.png',
#  'depth_00159.png',
#  'depth_00161.png',
#  'depth_00162.png',
#  'depth_00163.png',
#  'depth_00165.png',
#  'depth_00166.png',
#  'depth_00167.png',
#  'depth_00169.png',
#  'depth_00170.png',
#  'depth_00171.png',
#  'depth_00173.png',
#  'depth_00174.png',
#  'depth_00175.png',
#  'depth_00177.png',
#  'depth_00178.png',
#  'depth_00179.png',
#  'depth_00181.png',
#  'depth_00182.png',
#  'depth_00183.png',
#  'depth_00185.png',
#  'depth_00186.png',
#  'depth_00187.png',
#  'depth_00189.png',
#  'depth_00190.png',
#  'depth_00191.png',
#  'depth_00193.png',
#  'depth_00194.png',
#  'depth_00195.png',
#  'depth_00197.png',
#  'depth_00198.png',
#  'depth_00199.png',
#  'depth_00201.png',
#  'depth_00202.png',
#  'depth_00203.png',
#  'depth_00205.png',
#  'depth_00206.png',
#  'depth_00207.png',
#  'depth_00209.png',
#  'depth_00210.png',
#  'depth_00211.png',
#  'depth_00213.png',
#  'depth_00214.png',
#  'depth_00215.png',
#  'depth_00217.png',
#  'depth_00218.png',
#  'depth_00219.png',
#  'depth_00221.png',
#  'depth_00222.png',
#  'depth_00223.png',
#  'depth_00225.png',
#  'depth_00226.png',
#  'depth_00227.png',
#  'depth_00229.png',
#  'depth_00230.png',
#  'depth_00231.png',
#  'depth_00233.png',
#  'depth_00234.png',
#  'depth_00235.png',
#  'depth_00237.png',
#  'depth_00238.png',
#  'depth_00239.png',
#  'depth_00241.png',
#  'depth_00242.png',
#  'depth_00243.png',
#  'depth_00245.png',
#  'depth_00246.png',
#  'depth_00247.png',
#  'depth_00249.png',
#  'depth_00250.png',
#  'depth_00251.png',
#  'depth_00253.png',
#  'depth_00254.png',
#  'depth_00255.png',
#  'depth_00257.png',
#  'depth_00258.png',
#  'depth_00259.png',
#  'depth_00261.png',
#  'depth_00262.png',
#  'depth_00263.png',
#  'depth_00265.png',
#  'depth_00266.png',
#  'depth_00267.png',
#  'depth_00269.png',
#  'depth_00270.png',
#  'depth_00271.png',
#  'depth_00273.png',
#  'depth_00274.png',
#  'depth_00275.png',
#  'depth_00277.png',
#  'depth_00278.png',
#  'depth_00279.png',
#  'depth_00281.png',
#  'depth_00282.png',
#  'depth_00283.png',
#  'depth_00285.png',
#  'depth_00286.png',
#  'depth_00287.png',
#  'depth_00289.png',
#  'depth_00290.png',
#  'depth_00291.png',
#  'depth_00293.png',
#  'depth_00294.png',
#  'depth_00295.png',
#  'depth_00297.png',
#  'depth_00298.png',
#  'depth_00299.png',
#  'depth_00301.png',
#  'depth_00302.png',
#  'depth_00303.png',
#  'depth_00305.png',
#  'depth_00306.png',
#  'depth_00307.png',
#  'depth_00309.png',
#  'depth_00310.png',
#  'depth_00311.png',
#  'depth_00313.png',
#  'depth_00314.png',
#  'depth_00315.png',
#  'depth_00317.png',
#  'depth_00318.png',
#  'depth_00319.png',
#  'depth_00321.png',
#  'depth_00322.png',
#  'depth_00323.png',
#  'depth_00325.png',
#  'depth_00326.png',
#  'depth_00327.png',
#  'depth_00329.png',
#  'depth_00330.png',
#  'depth_00331.png',
#  'depth_00333.png',
#  'depth_00334.png',
#  'depth_00335.png',
#  'depth_00337.png',
#  'depth_00338.png',
#  'depth_00339.png',
#  'depth_00341.png',
#  'depth_00342.png',
#  'depth_00343.png',
#  'depth_00345.png',
#  'depth_00346.png',
#  'depth_00347.png',
#  'depth_00349.png',
#  'depth_00350.png',
#  'depth_00351.png',
#  'depth_00353.png',
#  'depth_00354.png',
#  'depth_00355.png',
#  'depth_00357.png',
#  'depth_00358.png',
#  'depth_00359.png',
#  'depth_00361.png',
#  'depth_00362.png',
#  'depth_00363.png',
#  'depth_00365.png',
#  'depth_00366.png',
#  'depth_00367.png',
#  'depth_00369.png',
#  'depth_00370.png',
#  'depth_00371.png',
#  'depth_00373.png',
#  'depth_00374.png',
#  'depth_00375.png',
#  'depth_00377.png',
#  'depth_00378.png',
#  'depth_00379.png',
#  'depth_00381.png',
#  'depth_00382.png',
#  'depth_00383.png',
#  'depth_00385.png',
#  'depth_00386.png',
#  'depth_00387.png',
#  'depth_00389.png',
#  'depth_00390.png',
#  'depth_00391.png',
#  'depth_00393.png',
#  'depth_00394.png',
#  'depth_00395.png',
#  'depth_00397.png',
#  'depth_00398.png',
#  'depth_00399.png',
#  'depth_00401.png',
#  'depth_00402.png',
#  'depth_00403.png',
#  'depth_00405.png',
#  'depth_00406.png',
#  'depth_00407.png',
#  'depth_00409.png',
#  'depth_00410.png',
#  'depth_00411.png',
#  'depth_00413.png',
#  'depth_00414.png',
#  'depth_00415.png',
#  'depth_00417.png',
#  'depth_00418.png',
#  'depth_00419.png',
#  'depth_00421.png',
#  'depth_00422.png',
#  'depth_00423.png',
#  'depth_00425.png',
#  'depth_00426.png',
#  'depth_00427.png',
#  'depth_00429.png',
#  'depth_00430.png',
#  'depth_00431.png',
#  'depth_00433.png',
#  'depth_00434.png',
#  'depth_00435.png',
#  'depth_00437.png',
#  'depth_00438.png',
#  'depth_00439.png',
#  'depth_00441.png',
#  'depth_00442.png',
#  'depth_00443.png',
#  'depth_00445.png',
#  'depth_00446.png',
#  'depth_00447.png',
#  'depth_00449.png',
#  'depth_00450.png',
#  'depth_00451.png',
#  'depth_00453.png',
#  'depth_00454.png',
#  'depth_00455.png',
#  'depth_00457.png',
#  'depth_00458.png',
#  'depth_00459.png',
#  'depth_00461.png',
#  'depth_00462.png',
#  'depth_00463.png',
#  'depth_00465.png',
#  'depth_00466.png',
#  'depth_00467.png',
#  'depth_00469.png',
#  'depth_00470.png',
#  'depth_00471.png',
#  'depth_00473.png',
#  'depth_00474.png',
#  'depth_00475.png',
#  'depth_00477.png',
#  'depth_00478.png',
#  'depth_00479.png',
#  'depth_00481.png',
#  'depth_00482.png',
#  'depth_00483.png',
#  'depth_00485.png',
#  'depth_00486.png',
#  'depth_00487.png',
#  'depth_00489.png',
#  'depth_00490.png',
#  'depth_00491.png',
#  'depth_00493.png',
#  'depth_00494.png',
#  'depth_00495.png',
#  'depth_00497.png',
#  'depth_00498.png',
#  'depth_00499.png',
#  'depth_00501.png',
#  'depth_00502.png',
#  'depth_00503.png',
#  'depth_00505.png',
#  'depth_00506.png',
#  'depth_00507.png',
#  'depth_00509.png',
#  'depth_00510.png',
#  'depth_00511.png',
#  'depth_00513.png',
#  'depth_00514.png',
#  'depth_00515.png',
#  'depth_00517.png',
#  'depth_00518.png',
#  'depth_00519.png',
#  'depth_00521.png',
#  'depth_00522.png',
#  'depth_00523.png',
#  'depth_00525.png',
#  'depth_00526.png',
#  'depth_00527.png',
#  'depth_00529.png',
#  'depth_00530.png',
#  'depth_00531.png',
#  'depth_00533.png',
#  'depth_00534.png',
#  'depth_00535.png',
#  'depth_00537.png',
#  'depth_00538.png',
#  'depth_00539.png',
#  'depth_00541.png',
#  'depth_00542.png',
#  'depth_00543.png',
#  'depth_00545.png',
#  'depth_00546.png',
#  'depth_00547.png',
#  'depth_00549.png',
#  'depth_00550.png',
#  'depth_00551.png',
#  'depth_00553.png',
#  'depth_00554.png',
#  'depth_00555.png',
#  'depth_00557.png',
#  'depth_00558.png',
#  'depth_00559.png',
#  'depth_00561.png',
#  'depth_00562.png',
#  'depth_00563.png',
#  'depth_00565.png',
#  'depth_00566.png',
#  'depth_00567.png',
#  'depth_00569.png',
#  'depth_00570.png',
#  'depth_00571.png',
#  'depth_00573.png',
#  'depth_00574.png',
#  'depth_00575.png',
#  'depth_00577.png',
#  'depth_00578.png',
#  'depth_00579.png',
#  'depth_00581.png',
#  'depth_00582.png',
#  'depth_00583.png',
#  'depth_00585.png',
#  'depth_00586.png',
#  'depth_00587.png',
#  'depth_00589.png',
#  'depth_00590.png',
#  'depth_00591.png',
#  'depth_00593.png',
#  'depth_00594.png',
#  'depth_00595.png',
#  'depth_00597.png',
#  'depth_00598.png',
#  'depth_00599.png',
#  'depth_00601.png',
#  'depth_00602.png',
#  'depth_00603.png',
#  'depth_00605.png',
#  'depth_00606.png',
#  'depth_00607.png',
#  'depth_00609.png',
#  'depth_00610.png',
#  'depth_00611.png',
#  'depth_00613.png',
#  'depth_00614.png',
#  'depth_00615.png',
#  'depth_00617.png',
#  'depth_00618.png',
#  'depth_00619.png',
#  'depth_00621.png',
#  'depth_00622.png',
#  'depth_00623.png',
#  'depth_00625.png',
#  'depth_00626.png',
#  'depth_00627.png',
#  'depth_00629.png',
#  'depth_00630.png',
#  'depth_00631.png',
#  'depth_00633.png',
#  'depth_00634.png',
#  'depth_00635.png',
#  'depth_00637.png',
#  'depth_00638.png',
#  'depth_00639.png',
#  'depth_00641.png',
#  'depth_00642.png',
#  'depth_00643.png',
#  'depth_00645.png',
#  'depth_00646.png',
#  'depth_00647.png',
#  'depth_00649.png',
#  'depth_00650.png',
#  'depth_00651.png',
#  'depth_00653.png',
#  'depth_00654.png',
#  'depth_00655.png',
#  'depth_00657.png',
#  'depth_00658.png',
#  'depth_00659.png',
#  'depth_00661.png',
#  'depth_00662.png',
#  'depth_00663.png',
#  'depth_00665.png',
#  'depth_00666.png',
#  'depth_00667.png',
#  'depth_00669.png',
#  'depth_00670.png',
#  'depth_00671.png',
#  'depth_00673.png',
#  'depth_00674.png',
#  'depth_00675.png',
#  'depth_00677.png',
#  'depth_00678.png',
#  'depth_00679.png',
#  'depth_00681.png',
#  'depth_00682.png',
#  'depth_00683.png',
#  'depth_00685.png',
#  'depth_00686.png',
#  'depth_00687.png',
#  'depth_00689.png',
#  'depth_00690.png',
#  'depth_00691.png',
#  'depth_00693.png',
#  'depth_00694.png',
#  'depth_00695.png',
#  'depth_00697.png',
#  'depth_00698.png',
#  'depth_00699.png',
#  'depth_00701.png',
#  'depth_00702.png',
#  'depth_00703.png',
#  'depth_00705.png',
#  'depth_00706.png',
#  'depth_00707.png',
#  'depth_00709.png',
#  'depth_00710.png',
#  'depth_00711.png',
#  'depth_00713.png',
#  'depth_00714.png',
#  'depth_00715.png',
#  'depth_00717.png',
#  'depth_00718.png',
#  'depth_00719.png',
#  'depth_00721.png',
#  'depth_00722.png',
#  'depth_00723.png',
#  'depth_00725.png',
#  'depth_00726.png',
#  'depth_00727.png',
#  'depth_00729.png',
#  'depth_00730.png',
#  'depth_00731.png',
#  'depth_00733.png',
#  'depth_00734.png',
#  'depth_00735.png',
#  'depth_00737.png',
#  'depth_00738.png',
#  'depth_00739.png',
#  'depth_00741.png',
#  'depth_00742.png',
#  'depth_00743.png',
#  'depth_00745.png',
#  'depth_00746.png',
#  'depth_00747.png',
#  'depth_00749.png',
#  'depth_00750.png',
#  'depth_00751.png',
#  'depth_00753.png',
#  'depth_00754.png',
#  'depth_00755.png',
#  'depth_00757.png',
#  'depth_00758.png',
#  'depth_00759.png',
#  'depth_00761.png',
#  'depth_00762.png',
#  'depth_00763.png',
#  'depth_00765.png',
#  'depth_00766.png',
#  'depth_00767.png',
#  'depth_00769.png',
#  'depth_00770.png',
#  'depth_00771.png',
#  'depth_00773.png',
#  'depth_00774.png',
#  'depth_00775.png',
#  'depth_00777.png',
#  'depth_00778.png',
#  'depth_00779.png',
#  'depth_00781.png',
#  'depth_00782.png',
#  'depth_00783.png',
#  'depth_00785.png',
#  'depth_00786.png',
#  'depth_00787.png',
#  'depth_00789.png',
#  'depth_00790.png',
#  'depth_00791.png',
#  'depth_00793.png',
#  'depth_00794.png',
#  'depth_00795.png',
#  'depth_00797.png',
#  'depth_00798.png',
#  'depth_00799.png',
#  'depth_00801.png',
#  'depth_00802.png',
#  'depth_00803.png',
#  'depth_00805.png',
#  'depth_00806.png',
#  'depth_00807.png',
#  'depth_00809.png',
#  'depth_00810.png',
#  'depth_00811.png',
#  'depth_00813.png',
#  'depth_00814.png',
#  'depth_00815.png',
#  'depth_00817.png',
#  'depth_00818.png',
#  'depth_00819.png',
#  'depth_00821.png',
#  'depth_00822.png',
#  'depth_00823.png',
#  'depth_00825.png',
#  'depth_00826.png',
#  'depth_00827.png',
#  'depth_00829.png',
#  'depth_00830.png',
#  'depth_00831.png',
#  'depth_00833.png',
#  'depth_00834.png',
#  'depth_00835.png',
#  'depth_00837.png',
#  'depth_00838.png',
#  'depth_00839.png',
#  'depth_00841.png',
#  'depth_00842.png',
#  'depth_00843.png',
#  'depth_00845.png',
#  'depth_00846.png',
#  'depth_00847.png',
#  'depth_00849.png',
#  'depth_00850.png',
#  'depth_00851.png',
#  'depth_00853.png',
#  'depth_00854.png',
#  'depth_00855.png',
#  'depth_00857.png',
#  'depth_00858.png',
#  'depth_00859.png',
#  'depth_00861.png',
#  'depth_00862.png',
#  'depth_00863.png',
#  'depth_00865.png',
#  'depth_00866.png',
#  'depth_00867.png',
#  'depth_00869.png',
#  'depth_00870.png',
#  'depth_00871.png',
#  'depth_00873.png',
#  'depth_00874.png',
#  'depth_00875.png',
#  'depth_00877.png',
#  'depth_00878.png',
#  'depth_00879.png',
#  'depth_00881.png',
#  'depth_00882.png',
#  'depth_00883.png',
#  'depth_00885.png',
#  'depth_00886.png',
#  'depth_00887.png',
#  'depth_00889.png',
#  'depth_00890.png',
#  'depth_00891.png',
#  'depth_00893.png',
#  'depth_00894.png',
#  'depth_00895.png',
#  'depth_00897.png',
#  'depth_00898.png',
#  'depth_00899.png']

# %%
import os
import shutil

# %%
# Paths to the directories
source_folder = '/home/rozenberszki/project/wsnsl/Datasets/Replica/room0_panoptic/results'
destination_folder = '/home/rozenberszki/project/wsnsl/Datasets/Replica/room0_panoptic/test_results'

# Ensure the destination folder exists
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# List of image names in the subset
subset_list = depths  # Add your image names here

# %%
# Loop through all files in the source folder
for file_name in os.listdir(source_folder):
    if file_name not in frames and file_name not in depths:
        # Full path of the file
        source_file_path = os.path.join(source_folder, file_name)
        destination_file_path = os.path.join(destination_folder, file_name)
        
        # Move the file
        shutil.move(source_file_path, destination_file_path)
        print(f'Moved: {file_name}')
# Out:
# Moved: frame_00856.png
# Moved: depth_00132.png
# Moved: frame_00684.png
# Moved: frame_00248.png
# Moved: depth_00192.png
# Moved: depth_00844.png
# Moved: depth_00652.png
# Moved: frame_00808.png
# Moved: depth_00372.png
# Moved: frame_00076.png
# Moved: frame_00724.png
# Moved: depth_00416.png
# Moved: frame_00296.png
# Moved: depth_00712.png
# Moved: frame_00532.png
# Moved: frame_00800.png
# Moved: depth_00556.png
# Moved: depth_00116.png
# Moved: frame_00460.png
# Moved: frame_00736.png
# Moved: depth_00284.png
# Moved: depth_00560.png
# Moved: depth_00640.png
# Moved: frame_00288.png
# Moved: depth_00860.png
# Moved: depth_00752.png
# Moved: frame_00840.png
# Moved: depth_00512.png
# Moved: frame_00516.png
# Moved: depth_00024.png
# Moved: frame_00020.png
# Moved: depth_00460.png
# Moved: depth_00196.png
# Moved: depth_00616.png
# Moved: frame_00052.png
# Moved: depth_00568.png
# Moved: depth_00336.png
# Moved: depth_00660.png
# Moved: depth_00376.png
# Moved: frame_00892.png
# Moved: frame_00124.png
# Moved: frame_00588.png
# Moved: frame_00852.png
# Moved: depth_00364.png
# Moved: frame_00136.png
# Moved: depth_00852.png
# Moved: frame_00168.png
# Moved: frame_00032.png
# Moved: depth_00020.png
# Moved: depth_00672.png
# Moved: depth_00152.png
# Moved: frame_00252.png
# Moved: frame_00468.png
# Moved: frame_00436.png
# Moved: frame_00876.png
# Moved: frame_00080.png
# Moved: depth_00600.png
# Moved: depth_00716.png
# Moved: depth_00396.png
# Moved: depth_00144.png
# Moved: frame_00488.png
# Moved: frame_00368.png
# Moved: frame_00200.png
# Moved: frame_00004.png
# Moved: frame_00116.png
# Moved: depth_00500.png
# Moved: depth_00736.png
# Moved: frame_00820.png
# Moved: frame_00888.png
# Moved: frame_00008.png
# Moved: frame_00548.png
# Moved: frame_00316.png
# Moved: depth_00344.png
# Moved: frame_00636.png
# Moved: depth_00760.png
# Moved: depth_00012.png
# Moved: depth_00488.png
# Moved: depth_00756.png
# Moved: depth_00440.png
# Moved: depth_00056.png
# Moved: frame_00100.png
# Moved: frame_00452.png
# Moved: depth_00668.png
# Moved: frame_00280.png
# Moved: frame_00676.png
# Moved: depth_00292.png
# Moved: frame_00148.png
# Moved: depth_00236.png
# Moved: frame_00508.png
# Moved: frame_00320.png
# Moved: depth_00836.png
# Moved: depth_00324.png
# Moved: depth_00064.png
# Moved: depth_00348.png
# Moved: depth_00456.png
# Moved: frame_00196.png
# Moved: depth_00128.png
# Moved: frame_00048.png
# Moved: depth_00008.png
# Moved: depth_00044.png
# Moved: depth_00508.png
# Moved: depth_00060.png
# Moved: depth_00256.png
# Moved: depth_00680.png
# Moved: frame_00696.png
# Moved: depth_00768.png
# Moved: frame_00432.png
# Moved: frame_00552.png
# Moved: frame_00780.png
# Moved: frame_00420.png
# Moved: frame_00256.png
# Moved: frame_00716.png
# Moved: frame_00120.png
# Moved: frame_00448.png
# Moved: depth_00188.png
# Moved: frame_00500.png
# Moved: depth_00332.png
# Moved: frame_00372.png
# Moved: frame_00536.png
# Moved: depth_00168.png
# Moved: frame_00212.png
# Moved: frame_00352.png
# Moved: frame_00132.png
# Moved: frame_00560.png
# Moved: frame_00376.png
# Moved: depth_00424.png
# Moved: depth_00648.png
# Moved: depth_00452.png
# Moved: depth_00864.png
# Moved: depth_00676.png
# Moved: depth_00888.png
# Moved: depth_00036.png
# Moved: depth_00208.png
# Moved: depth_00264.png
# Moved: depth_00848.png
# Moved: depth_00084.png
# Moved: frame_00056.png
# Moved: frame_00284.png
# Moved: depth_00300.png
# Moved: frame_00404.png
# Moved: depth_00356.png
# Moved: frame_00428.png
# Moved: frame_00524.png
# Moved: frame_00868.png
# Moved: frame_00712.png
# Moved: depth_00748.png
# Moved: frame_00732.png
# Moved: frame_00496.png
# Moved: frame_00392.png
# Moved: depth_00316.png
# Moved: frame_00620.png
# Moved: frame_00344.png
# Moved: depth_00420.png
# Moved: depth_00784.png
# Moved: depth_00576.png
# Moved: frame_00764.png
# Moved: frame_00604.png
# Moved: frame_00804.png
# Moved: depth_00108.png
# Moved: frame_00596.png
# Moved: frame_00472.png
# Moved: frame_00752.png
# Moved: frame_00624.png
# Moved: frame_00652.png
# Moved: depth_00808.png
# Moved: frame_00044.png
# Moved: frame_00580.png
# Moved: frame_00632.png
# Moved: frame_00844.png
# Moved: frame_00128.png
# Moved: depth_00744.png
# Moved: frame_00644.png
# Moved: depth_00828.png
# Moved: depth_00572.png
# Moved: frame_00096.png
# Moved: depth_00088.png
# Moved: frame_00272.png
# Moved: frame_00476.png
# Moved: frame_00492.png
# Moved: depth_00588.png
# Moved: depth_00092.png
# Moved: depth_00816.png
# Moved: depth_00780.png
# Moved: frame_00304.png
# Moved: frame_00400.png
# Moved: depth_00368.png
# Moved: depth_00528.png
# Moved: depth_00004.png
# Moved: depth_00392.png
# Moved: depth_00408.png
# Moved: depth_00612.png
# Moved: frame_00364.png
# Moved: depth_00412.png
# Moved: depth_00896.png
# Moved: frame_00012.png
# Moved: depth_00080.png
# Moved: frame_00864.png
# Moved: depth_00704.png
# Moved: frame_00228.png
# Moved: depth_00000.png
# Moved: depth_00472.png
# Moved: depth_00320.png
# Moved: depth_00252.png
# Moved: depth_00220.png
# Moved: frame_00824.png
# Moved: depth_00164.png
# Moved: depth_00200.png
# Moved: depth_00516.png
# Moved: frame_00616.png
# Moved: frame_00748.png
# Moved: frame_00172.png
# Moved: depth_00792.png
# Moved: frame_00260.png
# Moved: frame_00224.png
# Moved: frame_00220.png
# Moved: frame_00744.png
# Moved: depth_00840.png
# Moved: frame_00244.png
# Moved: depth_00228.png
# Moved: frame_00792.png
# Moved: depth_00040.png
# Moved: frame_00300.png
# Moved: depth_00764.png
# Moved: depth_00796.png
# Moved: depth_00632.png
# Moved: depth_00776.png
# Moved: depth_00868.png
# Moved: frame_00160.png
# Moved: depth_00176.png
# Moved: depth_00664.png
# Moved: frame_00040.png
# Moved: frame_00276.png
# Moved: frame_00192.png
# Moved: depth_00532.png
# Moved: frame_00084.png
# Moved: frame_00680.png
# Moved: depth_00072.png
# Moved: frame_00816.png
# Moved: frame_00672.png
# Moved: frame_00728.png
# Moved: depth_00384.png
# Moved: depth_00216.png
# Moved: frame_00060.png
# Moved: depth_00800.png
# Moved: frame_00544.png
# Moved: frame_00412.png
# Moved: depth_00584.png
# Moved: depth_00104.png
# Moved: depth_00892.png
# Moved: frame_00848.png
# Moved: depth_00544.png
# Moved: frame_00016.png
# Moved: depth_00636.png
# Moved: depth_00772.png
# Moved: frame_00164.png
# Moved: depth_00340.png
# Moved: frame_00384.png
# Moved: frame_00708.png
# Moved: depth_00628.png
# Moved: depth_00096.png
# Moved: frame_00564.png
# Moved: depth_00824.png
# Moved: frame_00408.png
# Moved: depth_00272.png
# Moved: depth_00692.png
# Moved: depth_00592.png
# Moved: frame_00828.png
# Moved: frame_00088.png
# Moved: depth_00788.png
# Moved: frame_00144.png
# Moved: frame_00784.png
# Moved: depth_00204.png
# Moved: depth_00536.png
# Moved: depth_00172.png
# Moved: depth_00136.png
# Moved: frame_00208.png
# Moved: depth_00260.png
# Moved: frame_00740.png
# Moved: frame_00860.png
# Moved: frame_00232.png
# Moved: frame_00640.png
# Moved: depth_00148.png
# Moved: frame_00896.png
# Moved: depth_00028.png
# Moved: depth_00596.png
# Moved: frame_00556.png
# Moved: depth_00180.png
# Moved: frame_00028.png
# Moved: frame_00024.png
# Moved: frame_00628.png
# Moved: depth_00524.png
# Moved: depth_00304.png
# Moved: depth_00504.png
# Moved: depth_00884.png
# Moved: frame_00720.png
# Moved: depth_00436.png
# Moved: frame_00788.png
# Moved: depth_00732.png
# Moved: depth_00804.png
# Moved: depth_00484.png
# Moved: frame_00424.png
# Moved: frame_00336.png
# Moved: frame_00036.png
# Moved: depth_00048.png
# Moved: depth_00428.png
# Moved: frame_00180.png
# Moved: frame_00416.png
# Moved: depth_00832.png
# Moved: frame_00332.png
# Moved: frame_00092.png
# Moved: depth_00244.png
# Moved: depth_00492.png
# Moved: frame_00576.png
# Moved: depth_00156.png
# Moved: depth_00224.png
# Moved: frame_00776.png
# Moved: depth_00112.png
# Moved: depth_00360.png
# Moved: frame_00648.png
# Moved: frame_00388.png
# Moved: frame_00324.png
# Moved: frame_00356.png
# Moved: frame_00396.png
# Moved: depth_00184.png
# Moved: frame_00768.png
# Moved: depth_00124.png
# Moved: frame_00380.png
# Moved: frame_00700.png
# Moved: depth_00052.png
# Moved: depth_00876.png
# Moved: frame_00540.png
# Moved: frame_00072.png
# Moved: frame_00572.png
# Moved: depth_00604.png
# Moved: frame_00064.png
# Moved: frame_00484.png
# Moved: frame_00592.png
# Moved: depth_00120.png
# Moved: depth_00812.png
# Moved: frame_00836.png
# Moved: depth_00580.png
# Moved: depth_00404.png
# Moved: depth_00032.png
# Moved: depth_00564.png
# Moved: frame_00456.png
# Moved: depth_00548.png
# Moved: depth_00232.png
# Moved: frame_00656.png
# Moved: frame_00268.png
# Moved: frame_00504.png
# Moved: frame_00156.png
# Moved: depth_00212.png
# Moved: frame_00608.png
# Moved: frame_00688.png
# Moved: frame_00796.png
# Moved: depth_00496.png
# Moved: depth_00312.png
# Moved: depth_00740.png
# Moved: depth_00656.png
# Moved: depth_00708.png
# Moved: frame_00236.png
# Moved: depth_00620.png
# Moved: frame_00772.png
# Moved: frame_00528.png
# Moved: depth_00140.png
# Moved: frame_00832.png
# Moved: depth_00444.png
# Moved: frame_00612.png
# Moved: depth_00160.png
# Moved: frame_00668.png
# Moved: frame_00440.png
# Moved: depth_00448.png
# Moved: depth_00076.png
# Moved: frame_00444.png
# Moved: depth_00016.png
# Moved: frame_00480.png
# Moved: depth_00296.png
# Moved: depth_00280.png
# Moved: frame_00204.png
# Moved: depth_00464.png
# Moved: frame_00216.png
# Moved: depth_00380.png
# Moved: frame_00760.png
# Moved: frame_00464.png
# Moved: depth_00100.png
# Moved: frame_00184.png
# Moved: frame_00312.png
# Moved: frame_00112.png
# Moved: depth_00240.png
# Moved: depth_00688.png
# Moved: depth_00724.png
# Moved: depth_00308.png
# Moved: depth_00696.png
# Moved: depth_00476.png
# Moved: frame_00692.png
# Moved: frame_00340.png
# Moved: depth_00248.png
# Moved: frame_00104.png
# Moved: frame_00812.png
# Moved: depth_00856.png
# Moved: frame_00880.png
# Moved: frame_00704.png
# Moved: depth_00880.png
# Moved: frame_00176.png
# Moved: frame_00584.png
# Moved: depth_00608.png
# Moved: frame_00152.png
# Moved: depth_00700.png
# Moved: frame_00664.png
# Moved: depth_00268.png
# Moved: depth_00540.png
# Moved: frame_00872.png
# Moved: depth_00480.png
# Moved: frame_00328.png
# Moved: depth_00872.png
# Moved: depth_00520.png
# Moved: depth_00644.png
# Moved: frame_00068.png
# Moved: frame_00240.png
# Moved: depth_00400.png
# Moved: frame_00292.png
# Moved: depth_00728.png
# Moved: frame_00264.png
# Moved: frame_00108.png
# Moved: depth_00468.png
# Moved: frame_00600.png
# Moved: depth_00328.png
# Moved: frame_00512.png
# Moved: depth_00276.png
# Moved: depth_00720.png
# Moved: frame_00884.png
# Moved: depth_00388.png
# Moved: frame_00520.png
# Moved: frame_00660.png
# Moved: depth_00068.png
# Moved: frame_00308.png
# Moved: frame_00568.png
# Moved: frame_00348.png
# Moved: depth_00820.png
# Moved: frame_00360.png
# Moved: depth_00352.png
# Moved: frame_00140.png
# Moved: frame_00188.png
# Moved: depth_00552.png
# Moved: depth_00684.png
# Moved: frame_00756.png
# Moved: depth_00288.png
# Moved: depth_00624.png
# Moved: frame_00000.png
# Moved: depth_00432.png

# %%
t = np.loadtxt('/home/rozenberszki/project/wsnsl/Datasets/Replica/room0_panoptic/traj_full.txt')

# %%
t = t.reshape(-1,4,4)
t.shape
# Out:
# (900, 4, 4)

# %%
n = [int(d.split('_')[1]) for d in data]
n = np.array(n)
t_split = t[n-1]

# %%
np.savetxt('/home/rozenberszki/project/wsnsl/Datasets/Replica/room0_panoptic/traj.txt', t_split.reshape(-1,16))

# %%
indices = np.arange(len(t))
indices_to_store = indices[~np.isin(indices, n-1)]
t_test = t[indices_to_store]

# %%
np.savetxt('/home/rozenberszki/project/wsnsl/Datasets/Replica/room0_panoptic/traj_test.txt', t_test.reshape(-1,16))
