# %%
import cv2
import numpy as np
import torch
from src.utils import create_instance_seg as cis
import glob
import pickle

# %%
path = "/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame*.jpg"

# %%
paths = sorted(glob.glob(path))
paths[:10]
# Out:
# ['/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000000.jpg',
#  '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000001.jpg',
#  '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000002.jpg',
#  '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000003.jpg',
#  '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000004.jpg',
#  '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000005.jpg',
#  '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000006.jpg',
#  '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000007.jpg',
#  '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000008.jpg',
#  '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/frame000009.jpg']

# %%
sam = cis.create_sam("cuda")

# %%
path = paths[0]

# %%
color_data = cv2.imread(path)
color_data = cv2.cvtColor(color_data, cv2.COLOR_BGR2RGB)

# %%
mask = sam.generate(color_data)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
store_path = path.replace('frame', 'mask').replace('jpg', 'pkl')
store_path
# Out:
# '/home/koerner/Project/nice-slam/Datasets/generated/room0/results/mask000000.pkl'

# %%
with open(store_path, 'wb') as f:
    pickle.dump(mask, f)
