# %%
import numpy as np
import backproject
import id_generation
import create_instance_seg as cis
import cv2

# %%
sam = cis.create_sam()

# %%
image = '/home/julius/Project/nice-slam/Datasets/Replica/room0/results/frame000000.jpg'

# %%
cis.create_instance_seg(image, "/home/julius/Project/nice-slam/segmentation/data/room0", sam)
# Out:
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000000.npy

# %%
import glob
color_paths = sorted(glob.glob('/home/julius/Project/nice-slam/Datasets/Replica/room0/results/frame*.jpg'))

# %%
color_paths = color_paths[0:201:5]

# %%
for path in color_paths:
    print(path)
    cis.create_instance_seg(path, "/home/julius/Project/nice-slam/segmentation/data/room0", sam)
    print("\n\n")
# Out:
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000000.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000005.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000010.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000015.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000020.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000025.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000030.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000035.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000040.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000045.npy
# (680, 1200, 3)
# /home/julius/Project/nice-slam/segmentation/data/room0/seg000050.npy
# (680, 1200, 3)
# ...
