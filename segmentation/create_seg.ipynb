# %%
import numpy as np
import backproject
import id_generation
import create_instance_seg as cis
import cv2

# %%
sam = cis.create_sam()

# %%
image = "/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000000.jpg"

# %%
def show_anns(anns):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x["area"]), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)
    img = np.ones(
        (
            sorted_anns[0]["segmentation"].shape[0],
            sorted_anns[0]["segmentation"].shape[1],
            4,
        )
    )
    img[:, :, 3] = 0
    for ann in sorted_anns:
        m = ann["segmentation"]
        color_mask = np.concatenate([np.random.random(3), [1]])
        img[m] = color_mask
    #   print("img row 0", img[0])
    ax.imshow(img)

# %%
cis.create_instance_seg(
    image,
    "/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/segmentation/data/room0_small",
    sam,
)
# Out:
# /Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/segmentation/data/room0_small/seg000000.npy

# %%
ans = np.load(
    "/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/segmentation/data/room0_small/seg000000.npy"
)

# %%
import glob

color_paths = sorted(
    glob.glob(
        "/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame*.jpg"
    )
)
color_paths = color_paths[::5]
print("color paths", color_paths)
# Out:
# color paths ['/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000000.jpg', '/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000005.jpg', '/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000010.jpg', '/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000015.jpg', '/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000020.jpg', '/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000025.jpg', '/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000030.jpg', '/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000035.jpg', '/Users/A200254469/Desktop/tum/20
# ...

# %%
for path in color_paths:
    print(path)
    cis.create_instance_seg(
        path,
        "/Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/segmentation/data/room0_small",
        sam,
    )
    print("\n\n")
# Out:
# /Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000000.jpg
# /Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/segmentation/data/room0_small/seg000000.npy
#
#
#
# /Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000005.jpg
# /Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/segmentation/data/room0_small/seg000005.npy
#
#
#
# /Users/A200254469/Desktop/tum/2024ws/advancedDL4CV/segment/nice-slam/Datasets/Replica/room0/results/frame000010.jpg
