# %%
import glob
from PIL import Image
import os
from src.utils import vis
import numpy as np
import matplotlib.pyplot as plt
import torch


def make_gif(frame_folder):
    frames = [Image.open(image) for image in sorted(glob.glob(f"{frame_folder}/*.jpg"))]
    print(frames)
    print(frame_folder)
    frame_one = frames[0]
    frame_one.save(
        os.path.join(frame_folder, frame_folder.split("/")[-1]+ ".gif"),
        format="GIF",
        append_images=frames,
        save_all=True,
        duration=100,
        loop=0,
    )

# %%
for path in os.listdir("Datasets/data"):
    make_gif(os.path.join("Datasets/data",path,"iphone/rgb"))
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1F2F10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB150>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB190>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB1D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB5D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB610>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB690>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB590>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1440 at 0x7F4D4E1FB6D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x14
# ...
