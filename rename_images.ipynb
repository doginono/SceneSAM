# %%
import os
import re
import shutil
from PIL import Image, ImageEnhance

def format_filename(filename):
    # Regex to find the number in the filename
    match = re.search(r'(\d+)', filename)
    if match:
        number = int(match.group(1))  # Get the number part and convert to integer
        # Reformat the filename with leading zeros (5 digits in total)
        new_filename = f"frame_{number:05}.png"
        return new_filename
    return filename  # Return the original if no number found

def copy_and_rename_files(source_dir, dest_dir, brightness_factor=1):
    # Check if destination directory exists, create if not
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    # List all files in the source directory
    files = [f for f in os.listdir(source_dir) if os.path.isfile(os.path.join(source_dir, f))]

    # Process each file
    for file in files:
        new_name = format_filename(file)
        src_path = os.path.join(source_dir, file)
        dest_path = os.path.join(dest_dir, new_name)
        with Image.open(src_path) as img:
                # Adjust brightness
                enhancer = ImageEnhance.Brightness(img)
                img_enhanced = enhancer.enhance(brightness_factor)

                # Save the adjusted image
                img_enhanced.save(dest_path)
        # Copy file from source to destination with the new name
        #shutil.copy2(src_path, dest_path)
        print(f"Copied and renamed and adjusted brightness{file} to {new_name}")

# Specify source and destination directories
source_directory = '/home/rozenberszki/project/wsnsl/Datasets/Replica/room0_panoptic/color_1'
destination_directory = '/home/rozenberszki/project/wsnsl/Datasets/Replica/room0_panoptic/results'
brightness_factor = 0.6

copy_and_rename_files(source_directory, destination_directory, brightness_factor)
# Out:
# Copied and renamed and adjusted brightnessrgb_631.png to frame_00631.png
# Copied and renamed and adjusted brightnessrgb_211.png to frame_00211.png
# Copied and renamed and adjusted brightnessrgb_628.png to frame_00628.png
# Copied and renamed and adjusted brightnessrgb_535.png to frame_00535.png
# Copied and renamed and adjusted brightnessrgb_295.png to frame_00295.png
# Copied and renamed and adjusted brightnessrgb_141.png to frame_00141.png
# Copied and renamed and adjusted brightnessrgb_769.png to frame_00769.png
# Copied and renamed and adjusted brightnessrgb_751.png to frame_00751.png
# Copied and renamed and adjusted brightnessrgb_35.png to frame_00035.png
# Copied and renamed and adjusted brightnessrgb_572.png to frame_00572.png
# Copied and renamed and adjusted brightnessrgb_415.png to frame_00415.png
# Copied and renamed and adjusted brightnessrgb_216.png to frame_00216.png
# Copied and renamed and adjusted brightnessrgb_725.png to frame_00725.png
# Copied and renamed and adjusted brightnessrgb_395.png to frame_00395.png
# Copied and renamed and adjusted brightnessrgb_313.png to frame_00313.png
# Copied and renamed and adjusted brightnessrgb_362.png to frame_00362.png
# Copied and renamed and adjusted brightnessrgb_879.png to frame_00879.png
# Copied and renamed and adjusted brightnessrgb_793.png to frame_00793.png
# Copied and renamed and adjusted brightnessrgb_340.png to frame_00340.png
# Copied and renamed and adjusted brightnessrgb_515.png to frame_00515.png
# Copied and renamed and adjusted brightnessrgb_210.png to frame_00210.png
# Copied and renamed and adjusted brightnessrgb_441.png to frame_00441.png
# Copied and renamed and adjusted brightnessrgb_837.png to frame_00837.png
# Copied and renamed and adjusted brightnessrgb_212.png to frame_00212.png
# Copied and renamed and adjusted brightnessrgb_536.png to frame_00536.png
# Copied and renamed and adjusted brightnessrgb_537.png to frame_00537.png
# Copied and renamed and adjusted brightnessrgb_410.png to frame_00410.png
# Copied and renamed and adjusted brightnessrgb_538.png to frame_00538.png
# Copied and renamed and adjusted brightnessrgb_73.png to frame_00073.png
# Copied and renamed and adjusted brightnessrgb_402.png to frame_00402.png
# Copied and renamed and adjusted brightnessrgb_853.png to frame_00853.png
# Copied and renamed and adjusted brightnessrgb_164.png to frame_00164.png
# Copied and renamed and adjusted brightnessrgb_424.png to frame_00424.png
# Copied and renamed and adjusted brightnessrgb_679.png to frame_00679.png
# Copied and renamed and adjusted brightnessrgb_126.png to frame_00126.png
# Copied and renamed and adjusted brightnessrgb_237.png to frame_00237.png
# Copied and renamed and adjusted brightnessrgb_456.png to frame_00456.png
# Copied and renamed and adjusted brightnessrgb_416.png to frame_00416.png
# Copied and renamed and adjusted brightnessrgb_422.png to frame_00422.png
# Copied and renamed and adjusted brightnessrgb_162.png to frame_00162.png
# Copied and renamed and adjusted brightnessrgb_796.png to frame_00796.png
# Copied and renamed and adjusted brightnessrgb_180.png to frame_00180.png
# Copied and renamed and adjusted brightnessrgb_523.png to frame_00523.png
# Copied and renamed and adjusted brightnessrgb_867.png to frame_00867.png
# Copied and renamed and adjusted brightnessrgb_95.png to frame_00095.png
# Copied and renamed and adjusted brightnessrgb_88.png to frame_00088.png
# Copied and renamed and adjusted brightnessrgb_608.png to frame_00608.png
# Copied and renamed and adjusted brightnessrgb_26.png to frame_00026.png
# Copied and renamed and adjusted brightnessrgb_654.png to frame_00654.png
# Copied and renamed and adjusted brightnessrgb_667.png to frame_00667.png
# Copied and renamed and adjusted brightnessrgb_681.png to frame_00681.png
# Copied and renamed and adjusted brightnessrgb_265.png to frame_00265.png
# Copied and renamed and adjusted brightnessrgb_31.png to frame_00031.png
# Copied and renamed and adjusted brightnessrgb_157.png to frame_00157.png
# Copied and renamed and adjusted brightnessrgb_792.png to frame_00792.png
# Copied and renamed and adjusted brightnessrgb_450.png to frame_00450.png
# Copied and renamed and adjusted brightnessrgb_878.png to frame_00878.png
# Copied and renamed and adjusted brightnessrgb_343.png to frame_00343.png
# Copied and renamed and adjusted brightnessrgb_169.png to frame_00169.png
# Copied and renamed and adjusted brightnessrgb_124.png to frame_00124.png
# Copied and renamed and adjusted brightnessrgb_240.png to frame_00240.png
# Copied and renamed and adjusted brightnessrgb_63.png to frame_00063.png
# Copied and renamed and adjusted brightnessrgb_764.png to frame_00764.png
# Copied and renamed and adjusted brightnessrgb_539.png to frame_00539.png
# Copied and renamed and adjusted brightnessrgb_214.png to frame_00214.png
# Copied and renamed and adjusted brightnessrgb_525.png to frame_00525.png
# Copied and renamed and adjusted brightnessrgb_706.png to frame_00706.png
# Copied and renamed and adjusted brightnessrgb_325.png to frame_00325.png
# Copied and renamed and adjusted brightnessrgb_671.png to frame_00671.png
# Copied and renamed and adjusted brightnessrgb_110.png to frame_00110.png
# Copied and renamed and adjusted brightnessrgb_607.png to frame_00607.png
# Copied and renamed and adjusted brightnessrgb_765.png to frame_00765.png
# Copied and renamed and adjusted brightnessrgb_512.png to frame_00512.png
# Copied and renamed and adjusted brightnessrgb_470.png to frame_00470.png
# Copied and renamed and adjusted brightnessrgb_409.png to frame_00409.png
# Copied and renamed and adjusted brightnessrgb_442.png to frame_00442.png
# Copied and renamed and adjusted brightnessrgb_595.png to frame_00595.png
# Copied and renamed and adjusted brightnessrgb_733.png to frame_00733.png
# Copied and renamed and adjusted brightnessrgb_218.png to frame_00218.png
# Copied and renamed and adjusted brightnessrgb_101.png to frame_00101.png
# Copied and renamed and adjusted brightnessrgb_250.png to frame_00250.png
# Copied and renamed and adjusted brightnessrgb_99.png to frame_00099.png
# Copied and renamed and adjusted brightnessrgb_258.png to frame_00258.png
# Copied and renamed and adjusted brightnessrgb_807.png to frame_00807.png
# Copied and renamed and adjusted brightnessrgb_511.png to frame_00511.png
# Copied and renamed and adjusted brightnessrgb_788.png to frame_00788.png
# Copied and renamed and adjusted brightnessrgb_166.png to frame_00166.png
# Copied and renamed and adjusted brightnessrgb_39.png to frame_00039.png
# Copied and renamed and adjusted brightnessrgb_48.png to frame_00048.png
# Copied and renamed and adjusted brightnessrgb_530.png to frame_00530.png
# Copied and renamed and adjusted brightnessrgb_677.png to frame_00677.png
# Copied and renamed and adjusted brightnessrgb_109.png to frame_00109.png
# Copied and renamed and adjusted brightnessrgb_417.png to frame_00417.png
# Copied and renamed and adjusted brightnessrgb_249.png to frame_00249.png
# Copied and renamed and adjusted brightnessrgb_760.png to frame_00760.png
# Copied and renamed and adjusted brightnessrgb_682.png to frame_00682.png
# Copied and renamed and adjusted brightnessrgb_709.png to frame_00709.png
# Copied and renamed and adjusted brightnessrgb_72.png to frame_00072.png
# Copied and renamed and adjusted brightnessrgb_528.png to frame_00528.png
# Copied and renamed and adjusted brightnessrgb_86.png to frame_00086.png
# Copied and renamed and adjusted brightnessrgb_242.png to frame_00242.png
# Copied and renamed and adjusted brightnessrgb_692.png to frame_00692.png
# Copied and renamed and adjusted brightnessrgb_855.png to frame_00855.png
# Copied and renamed and adjusted brightnessrgb_701.png to frame_00701.png
# Copied and renamed and adjusted brightnessrgb_722.png to frame_00722.png
# Copied and renamed and adjusted brightnessrgb_298.png to frame_00298.png
# Copied and renamed and adjusted brightnessrgb_170.png to frame_00170.png
# Copied and renamed and adjusted brightnessrgb_808.png to frame_00808.png
# Copied and renamed and adjusted brightnessrgb_309.png to frame_00309.png
# Copied and renamed and adjusted brightnessrgb_423.png to frame_00423.png
# Copied and renamed and adjusted brightnessrgb_731.png to frame_00731.png
# Copied and renamed and adjusted brightnessrgb_38.png to frame_00038.png
# Copied and renamed and adjusted brightnessrgb_302.png to frame_00302.png
# Copied and renamed and adjusted brightnessrgb_127.png to frame_00127.png
# Copied and renamed and adjusted brightnessrgb_797.png to frame_00797.png
# Copied and renamed and adjusted brightnessrgb_599.png to frame_00599.png
# Copied and renamed and adjusted brightnessrgb_513.png to frame_00513.png
# Copied and renamed and adjusted brightnessrgb_568.png to frame_00568.png
# Copied and renamed and adjusted brightnessrgb_554.png to frame_00554.png
# Copied and renamed and adjusted brightnessrgb_703.png to frame_00703.png
# Copied and renamed and adjusted brightnessrgb_248.png to frame_00248.png
# Copied and renamed and adjusted brightnessrgb_78.png to frame_00078.png
# Copied and renamed and adjusted brightnessrgb_321.png to frame_00321.png
# Copied and renamed and adjusted brightnessrgb_880.png to frame_00880.png
# Copied and renamed and adjusted brightnessrgb_355.png to frame_00355.png
# Copied and renamed and adjusted brightnessrgb_843.png to frame_00843.png
# Copied and renamed and adjusted brightnessrgb_592.png to frame_00592.png
# Copied and renamed and adjusted brightnessrgb_822.png to frame_00822.png
# Copied and renamed and adjusted brightnessrgb_729.png to frame_00729.png
# Copied and renamed and adjusted brightnessrgb_651.png to frame_00651.png
# Copied and renamed and adjusted brightnessrgb_432.png to frame_00432.png
# Copied and renamed and adjusted brightnessrgb_202.png to frame_00202.png
# Copied and renamed and adjusted brightnessrgb_222.png to frame_00222.png
# Copied and renamed and adjusted brightnessrgb_6.png to frame_00006.png
# Copied and renamed and adjusted brightnessrgb_887.png to frame_00887.png
# Copied and renamed and adjusted brightnessrgb_868.png to frame_00868.png
# Copied and renamed and adjusted brightnessrgb_268.png to frame_00268.png
# Copied and renamed and adjusted brightnessrgb_229.png to frame_00229.png
# Copied and renamed and adjusted brightnessrgb_244.png to frame_00244.png
# Copied and renamed and adjusted brightnessrgb_376.png to frame_00376.png
# Copied and renamed and adjusted brightnessrgb_440.png to frame_00440.png
# Copied and renamed and adjusted brightnessrgb_431.png to frame_00431.png
# Copied and renamed and adjusted brightnessrgb_190.png to frame_00190.png
# Copied and renamed and adjusted brightnessrgb_111.png to frame_00111.png
# Copied and renamed and adjusted brightnessrgb_471.png to frame_00471.png
# Copied and renamed and adjusted brightnessrgb_490.png to frame_00490.png
# Copied and renamed and adjusted brightnessrgb_310.png to frame_00310.png
# Copied and renamed and adjusted brightnessrgb_580.png to frame_00580.png
# Copied and renamed and adjusted brightnessrgb_153.png to frame_00153.png
# Copied and renamed and adjusted brightnessrgb_618.png to frame_00618.png
# Copied and renamed and adjusted brightnessrgb_620.png to frame_00620.png
# Copied and renamed and adjusted brightnessrgb_297.png to frame_00297.png
# Copied and renamed and adjusted brightnessrgb_334.png to frame_00334.png
# Copied and renamed and adjusted brightnessrgb_25.png to frame_00025.png
# Copied and renamed and adjusted brightnessrgb_562.png to frame_00562.png
# Copied and renamed and adjusted brightnessrgb_561.png to frame_00561.png
# Copied and renamed and adjusted brightnessrgb_745.png to frame_00745.png
# Copied and renamed and adjusted brightnessrgb_564.png to frame_00564.png
# Copied and renamed and adjusted brightnessrgb_559.png to frame_00559.png
# Copied and renamed and adjusted brightnessrgb_104.png to frame_00104.png
# Copied and renamed and adjusted brightnessrgb_287.png to frame_00287.png
# Copied and renamed and adjusted brightnessrgb_50.png to frame_00050.png
# Copied and renamed and adjusted brightnessrgb_232.png to frame_00232.png
# Copied and renamed and adjusted brightnessrgb_670.png to frame_00670.png
# Copied and renamed and adjusted brightnessrgb_397.png to frame_00397.png
# Copied and renamed and adjusted brightnessrgb_587.png to frame_00587.png
# Copied and renamed and adjusted brightnessrgb_17.png to frame_00017.png
# Copied and renamed and adjusted brightnessrgb_662.png to frame_00662.png
# Copied and renamed and adjusted brightnessrgb_877.png to frame_00877.png
# Copied and renamed and adjusted brightnessrgb_784.png to frame_00784.png
# Copied and renamed and adjusted brightnessrgb_517.png to frame_00517.png
# Copied and renamed and adjusted brightnessrgb_79.png to frame_00079.png
# Copied and renamed and adjusted brightnessrgb_869.png to frame_00869.png
# Copied and renamed and adjusted brightnessrgb_547.png to frame_00547.png
# Copied and renamed and adjusted brightnessrgb_451.png to frame_00451.png
# Copied and renamed and adjusted brightnessrgb_293.png to frame_00293.png
# Copied and renamed and adjusted brightnessrgb_221.png to frame_00221.png
# Copied and renamed and adjusted brightnessrgb_894.png to frame_00894.png
# Copied and renamed and adjusted brightnessrgb_659.png to frame_00659.png
# Copied and renamed and adjusted brightnessrgb_519.png to frame_00519.png
# Copied and renamed and adjusted brightnessrgb_754.png to frame_00754.png
# Copied and renamed and adjusted brightnessrgb_645.png to frame_00645.png
# Copied and renamed and adjusted brightnessrgb_191.png to frame_00191.png
# Copied and renamed and adjusted brightnessrgb_217.png to frame_00217.png
# Copied and renamed and adjusted brightnessrgb_370.png to frame_00370.png
# Copied and renamed and adjusted brightnessrgb_459.png to frame_00459.png
# Copied and renamed and adjusted brightnessrgb_862.png to frame_00862.png
# Copied and renamed and adjusted brightnessrgb_178.png to frame_00178.png
# Copied and renamed and adjusted brightnessrgb_583.png to frame_00583.png
# Copied and renamed and adjusted brightnessrgb_358.png to frame_00358.png
# Copied and renamed and adjusted brightnessrgb_208.png to frame_00208.png
# Copied and renamed and adjusted brightnessrgb_694.png to frame_00694.png
# Copied and renamed and adjusted brightnessrgb_158.png to frame_00158.png
# Copied and renamed and adjusted brightnessrgb_815.png to frame_00815.png
# Copied and renamed and adjusted brightnessrgb_601.png to frame_00601.png
# Copied and renamed and adjusted brightnessrgb_768.png to frame_00768.png
# Copied and renamed and adjusted brightnessrgb_403.png to frame_00403.png
# Copied and renamed and adjusted brightnessrgb_371.png to frame_00371.png
# Copied and renamed and adjusted brightnessrgb_255.png to frame_00255.png
# Copied and renamed and adjusted brightnessrgb_648.png to frame_00648.png
# Copied and renamed and adjusted brightnessrgb_342.png to frame_00342.png
# Copied and renamed and adjusted brightnessrgb_714.png to frame_00714.png
# Copied and renamed and adjusted brightnessrgb_264.png to frame_00264.png
# Copied and renamed and adjusted brightnessrgb_861.png to frame_00861.png
# Copied and renamed and adjusted brightnessrgb_333.png to frame_00333.png
# Copied and renamed and adjusted brightnessrgb_401.png to frame_00401.png
# Copied and renamed and adjusted brightnessrgb_387.png to frame_00387.png
# Copied and renamed and adjusted brightnessrgb_695.png to frame_00695.png
# Copied and renamed and adjusted brightnessrgb_239.png to frame_00239.png
# Copied and renamed and adjusted brightnessrgb_207.png to frame_00207.png
# Copied and renamed and adjusted brightnessrgb_434.png to frame_00434.png
# Copied and renamed and adjusted brightnessrgb_228.png to frame_00228.png
# Copied and renamed and adjusted brightnessrgb_223.png to frame_00223.png
# Copied and renamed and adjusted brightnessrgb_647.png to frame_00647.png
# Copied and renamed and adjusted brightnessrgb_873.png to frame_00873.png
# Copied and renamed and adjusted brightnessrgb_455.png to frame_00455.png
# Copied and renamed and adjusted brightnessrgb_522.png to frame_00522.png
# Copied and renamed and adjusted brightnessrgb_159.png to frame_00159.png
# Copied and renamed and adjusted brightnessrgb_653.png to frame_00653.png
# Copied and renamed and adjusted brightnessrgb_546.png to frame_00546.png
# Copied and renamed and adjusted brightnessrgb_9.png to frame_00009.png
# Copied and renamed and adjusted brightnessrgb_738.png to frame_00738.png
# Copied and renamed and adjusted brightnessrgb_491.png to frame_00491.png
# Copied and renamed and adjusted brightnessrgb_529.png to frame_00529.png
# Copied and renamed and adjusted brightnessrgb_301.png to frame_00301.png
# Copied and renamed and adjusted brightnessrgb_271.png to frame_00271.png
# Copied and renamed and adjusted brightnessrgb_318.png to frame_00318.png
# Copied and renamed and adjusted brightnessrgb_646.png to frame_00646.png
# Copied and renamed and adjusted brightnessrgb_756.png to frame_00756.png
# Copied and renamed and adjusted brightnessrgb_504.png to frame_00504.png
# Copied and renamed and adjusted brightnessrgb_492.png to frame_00492.png
# Copied and renamed and adjusted brightnessrgb_444.png to frame_00444.png
# Copied and renamed and adjusted brightnessrgb_384.png to frame_00384.png
# Copied and renamed and adjusted brightnessrgb_863.png to frame_00863.png
# Copied and renamed and adjusted brightnessrgb_46.png to frame_00046.png
# Copied and renamed and adjusted brightnessrgb_83.png to frame_00083.png
# Copied and renamed and adjusted brightnessrgb_354.png to frame_00354.png
# Copied and renamed and adjusted brightnessrgb_469.png to frame_00469.png
# Copied and renamed and adjusted brightnessrgb_254.png to frame_00254.png
# Copied and renamed and adjusted brightnessrgb_828.png to frame_00828.png
# Copied and renamed and adjusted brightnessrgb_516.png to frame_00516.png
# Copied and renamed and adjusted brightnessrgb_439.png to frame_00439.png
# Copied and renamed and adjusted brightnessrgb_711.png to frame_00711.png
# Copied and renamed and adjusted brightnessrgb_437.png to frame_00437.png
# Copied and renamed and adjusted brightnessrgb_526.png to frame_00526.png
# Copied and renamed and adjusted brightnessrgb_859.png to frame_00859.png
# Copied and renamed and adjusted brightnessrgb_545.png to frame_00545.png
# Copied and renamed and adjusted brightnessrgb_196.png to frame_00196.png
# Copied and renamed and adjusted brightnessrgb_13.png to frame_00013.png
# Copied and renamed and adjusted brightnessrgb_813.png to frame_00813.png
# Copied and renamed and adjusted brightnessrgb_139.png to frame_00139.png
# Copied and renamed and adjusted brightnessrgb_204.png to frame_00204.png
# Copied and renamed and adjusted brightnessrgb_726.png to frame_00726.png
# Copied and renamed and adjusted brightnessrgb_263.png to frame_00263.png
# Copied and renamed and adjusted brightnessrgb_319.png to frame_00319.png
# Copied and renamed and adjusted brightnessrgb_463.png to frame_00463.png
# Copied and renamed and adjusted brightnessrgb_143.png to frame_00143.png
# Copied and renamed and adjusted brightnessrgb_831.png to frame_00831.png
# Copied and renamed and adjusted brightnessrgb_495.png to frame_00495.png
# Copied and renamed and adjusted brightnessrgb_839.png to frame_00839.png
# Copied and renamed and adjusted brightnessrgb_641.png to frame_00641.png
# Copied and renamed and adjusted brightnessrgb_378.png to frame_00378.png
# Copied and renamed and adjusted brightnessrgb_449.png to frame_00449.png
# Copied and renamed and adjusted brightnessrgb_844.png to frame_00844.png
# Copied and renamed and adjusted brightnessrgb_510.png to frame_00510.png
# Copied and renamed and adjusted brightnessrgb_634.png to frame_00634.png
# Copied and renamed and adjusted brightnessrgb_484.png to frame_00484.png
# Copied and renamed and adjusted brightnessrgb_746.png to frame_00746.png
# Copied and renamed and adjusted brightnessrgb_136.png to frame_00136.png
# Copied and renamed and adjusted brightnessrgb_14.png to frame_00014.png
# Copied and renamed and adjusted brightnessrgb_12.png to frame_00012.png
# Copied and renamed and adjusted brightnessrgb_205.png to frame_00205.png
# Copied and renamed and adjusted brightnessrgb_632.png to frame_00632.png
# Copied and renamed and adjusted brightnessrgb_573.png to frame_00573.png
# Copied and renamed and adjusted brightnessrgb_850.png to frame_00850.png
# Copied and renamed and adjusted brightnessrgb_62.png to frame_00062.png
# Copied and renamed and adjusted brightnessrgb_433.png to frame_00433.png
# Copied and renamed and adjusted brightnessrgb_482.png to frame_00482.png
# Copied and renamed and adjusted brightnessrgb_227.png to frame_00227.png
# Copied and renamed and adjusted brightnessrgb_337.png to frame_00337.png
# Copied and renamed and adjusted brightnessrgb_230.png to frame_00230.png
# Copied and renamed and adjusted brightnessrgb_219.png to frame_00219.png
# Copied and renamed and adjusted brightnessrgb_405.png to frame_00405.png
# Copied and renamed and adjusted brightnessrgb_702.png to frame_00702.png
# Copied and renamed and adjusted brightnessrgb_625.png to frame_00625.png
# Copied and renamed and adjusted brightnessrgb_668.png to frame_00668.png
# Copied and renamed and adjusted brightnessrgb_276.png to frame_00276.png
# Copied and renamed and adjusted brightnessrgb_283.png to frame_00283.png
# Copied and renamed and adjusted brightnessrgb_172.png to frame_00172.png
# Copied and renamed and adjusted brightnessrgb_37.png to frame_00037.png
# Copied and renamed and adjusted brightnessrgb_192.png to frame_00192.png
# Copied and renamed and adjusted brightnessrgb_600.png to frame_00600.png
# Copied and renamed and adjusted brightnessrgb_777.png to frame_00777.png
# Copied and renamed and adjusted brightnessrgb_678.png to frame_00678.png
# Copied and renamed and adjusted brightnessrgb_447.png to frame_00447.png
# Copied and renamed and adjusted brightnessrgb_259.png to frame_00259.png
# Copied and renamed and adjusted brightnessrgb_892.png to frame_00892.png
# Copied and renamed and adjusted brightnessrgb_427.png to frame_00427.png
# Copied and renamed and adjusted brightnessrgb_494.png to frame_00494.png
# Copied and renamed and adjusted brightnessrgb_690.png to frame_00690.png
# Copied and renamed and adjusted brightnessrgb_266.png to frame_00266.png
# Copied and renamed and adjusted brightnessrgb_570.png to frame_00570.png
# Copied and renamed and adjusted brightnessrgb_66.png to frame_00066.png
# Copied and renamed and adjusted brightnessrgb_803.png to frame_00803.png
# Copied and renamed and adjusted brightnessrgb_200.png to frame_00200.png
# Copied and renamed and adjusted brightnessrgb_737.png to frame_00737.png
# Copied and renamed and adjusted brightnessrgb_160.png to frame_00160.png
# Copied and renamed and adjusted brightnessrgb_426.png to frame_00426.png
# Copied and renamed and adjusted brightnessrgb_273.png to frame_00273.png
# Copied and renamed and adjusted brightnessrgb_419.png to frame_00419.png
# Copied and renamed and adjusted brightnessrgb_74.png to frame_00074.png
# Copied and renamed and adjusted brightnessrgb_269.png to frame_00269.png
# Copied and renamed and adjusted brightnessrgb_194.png to frame_00194.png
# Copied and renamed and adjusted brightnessrgb_717.png to frame_00717.png
# Copied and renamed and adjusted brightnessrgb_827.png to frame_00827.png
# Copied and renamed and adjusted brightnessrgb_518.png to frame_00518.png
# Copied and renamed and adjusted brightnessrgb_69.png to frame_00069.png
# Copied and renamed and adjusted brightnessrgb_398.png to frame_00398.png
# Copied and renamed and adjusted brightnessrgb_251.png to frame_00251.png
# Copied and renamed and adjusted brightnessrgb_353.png to frame_00353.png
# Copied and renamed and adjusted brightnessrgb_578.png to frame_00578.png
# Copied and renamed and adjusted brightnessrgb_224.png to frame_00224.png
# Copied and renamed and adjusted brightnessrgb_303.png to frame_00303.png
# Copied and renamed and adjusted brightnessrgb_112.png to frame_00112.png
# Copied and renamed and adjusted brightnessrgb_665.png to frame_00665.png
# Copied and renamed and adjusted brightnessrgb_460.png to frame_00460.png
# Copied and renamed and adjusted brightnessrgb_236.png to frame_00236.png
# Copied and renamed and adjusted brightnessrgb_616.png to frame_00616.png
# Copied and renamed and adjusted brightnessrgb_56.png to frame_00056.png
# Copied and renamed and adjusted brightnessrgb_811.png to frame_00811.png
# Copied and renamed and adjusted brightnessrgb_61.png to frame_00061.png
# Copied and renamed and adjusted brightnessrgb_364.png to frame_00364.png
# Copied and renamed and adjusted brightnessrgb_290.png to frame_00290.png
# Copied and renamed and adjusted brightnessrgb_744.png to frame_00744.png
# Copied and renamed and adjusted brightnessrgb_382.png to frame_00382.png
# Copied and renamed and adjusted brightnessrgb_663.png to frame_00663.png
# Copied and renamed and adjusted brightnessrgb_115.png to frame_00115.png
# Copied and renamed and adjusted brightnessrgb_349.png to frame_00349.png
# Copied and renamed and adjusted brightnessrgb_277.png to frame_00277.png
# Copied and renamed and adjusted brightnessrgb_335.png to frame_00335.png
# Copied and renamed and adjusted brightnessrgb_193.png to frame_00193.png
# Copied and renamed and adjusted brightnessrgb_149.png to frame_00149.png
# Copied and renamed and adjusted brightnessrgb_414.png to frame_00414.png
# Copied and renamed and adjusted brightnessrgb_781.png to frame_00781.png
# Copied and renamed and adjusted brightnessrgb_753.png to frame_00753.png
# Copied and renamed and adjusted brightnessrgb_328.png to frame_00328.png
# Copied and renamed and adjusted brightnessrgb_365.png to frame_00365.png
# Copied and renamed and adjusted brightnessrgb_443.png to frame_00443.png
# Copied and renamed and adjusted brightnessrgb_235.png to frame_00235.png
# Copied and renamed and adjusted brightnessrgb_520.png to frame_00520.png
# Copied and renamed and adjusted brightnessrgb_558.png to frame_00558.png
# Copied and renamed and adjusted brightnessrgb_59.png to frame_00059.png
# Copied and renamed and adjusted brightnessrgb_673.png to frame_00673.png
# Copied and renamed and adjusted brightnessrgb_734.png to frame_00734.png
# Copied and renamed and adjusted brightnessrgb_623.png to frame_00623.png
# Copied and renamed and adjusted brightnessrgb_740.png to frame_00740.png
# Copied and renamed and adjusted brightnessrgb_550.png to frame_00550.png
# Copied and renamed and adjusted brightnessrgb_406.png to frame_00406.png
# Copied and renamed and adjusted brightnessrgb_543.png to frame_00543.png
# Copied and renamed and adjusted brightnessrgb_10.png to frame_00010.png
# Copied and renamed and adjusted brightnessrgb_761.png to frame_00761.png
# Copied and renamed and adjusted brightnessrgb_704.png to frame_00704.png
# Copied and renamed and adjusted brightnessrgb_478.png to frame_00478.png
# Copied and renamed and adjusted brightnessrgb_610.png to frame_00610.png
# Copied and renamed and adjusted brightnessrgb_40.png to frame_00040.png
# Copied and renamed and adjusted brightnessrgb_541.png to frame_00541.png
# Copied and renamed and adjusted brightnessrgb_852.png to frame_00852.png
# Copied and renamed and adjusted brightnessrgb_590.png to frame_00590.png
# Copied and renamed and adjusted brightnessrgb_527.png to frame_00527.png
# Copied and renamed and adjusted brightnessrgb_132.png to frame_00132.png
# Copied and renamed and adjusted brightnessrgb_82.png to frame_00082.png
# Copied and renamed and adjusted brightnessrgb_114.png to frame_00114.png
# Copied and renamed and adjusted brightnessrgb_500.png to frame_00500.png
# Copied and renamed and adjusted brightnessrgb_85.png to frame_00085.png
# Copied and renamed and adjusted brightnessrgb_117.png to frame_00117.png
# Copied and renamed and adjusted brightnessrgb_540.png to frame_00540.png
# Copied and renamed and adjusted brightnessrgb_800.png to frame_00800.png
# Copied and renamed and adjusted brightnessrgb_345.png to frame_00345.png
# Copied and renamed and adjusted brightnessrgb_133.png to frame_00133.png
# Copied and renamed and adjusted brightnessrgb_842.png to frame_00842.png
# Copied and renamed and adjusted brightnessrgb_585.png to frame_00585.png
# Copied and renamed and adjusted brightnessrgb_234.png to frame_00234.png
# Copied and renamed and adjusted brightnessrgb_476.png to frame_00476.png
# Copied and renamed and adjusted brightnessrgb_485.png to frame_00485.png
# Copied and renamed and adjusted brightnessrgb_461.png to frame_00461.png
# Copied and renamed and adjusted brightnessrgb_122.png to frame_00122.png
# Copied and renamed and adjusted brightnessrgb_854.png to frame_00854.png
# Copied and renamed and adjusted brightnessrgb_356.png to frame_00356.png
# Copied and renamed and adjusted brightnessrgb_116.png to frame_00116.png
# Copied and renamed and adjusted brightnessrgb_331.png to frame_00331.png
# Copied and renamed and adjusted brightnessrgb_532.png to frame_00532.png
# Copied and renamed and adjusted brightnessrgb_786.png to frame_00786.png
# Copied and renamed and adjusted brightnessrgb_203.png to frame_00203.png
# Copied and renamed and adjusted brightnessrgb_614.png to frame_00614.png
# Copied and renamed and adjusted brightnessrgb_840.png to frame_00840.png
# Copied and renamed and adjusted brightnessrgb_350.png to frame_00350.png
# Copied and renamed and adjusted brightnessrgb_174.png to frame_00174.png
# Copied and renamed and adjusted brightnessrgb_579.png to frame_00579.png
# Copied and renamed and adjusted brightnessrgb_396.png to frame_00396.png
# Copied and renamed and adjusted brightnessrgb_213.png to frame_00213.png
# Copied and renamed and adjusted brightnessrgb_138.png to frame_00138.png
# Copied and renamed and adjusted brightnessrgb_798.png to frame_00798.png
# Copied and renamed and adjusted brightnessrgb_179.png to frame_00179.png
# Copied and renamed and adjusted brightnessrgb_652.png to frame_00652.png
# Copied and renamed and adjusted brightnessrgb_845.png to frame_00845.png
# Copied and renamed and adjusted brightnessrgb_260.png to frame_00260.png
# Copied and renamed and adjusted brightnessrgb_674.png to frame_00674.png
# Copied and renamed and adjusted brightnessrgb_858.png to frame_00858.png
# Copied and renamed and adjusted brightnessrgb_238.png to frame_00238.png
# Copied and renamed and adjusted brightnessrgb_278.png to frame_00278.png
# Copied and renamed and adjusted brightnessrgb_591.png to frame_00591.png
# Copied and renamed and adjusted brightnessrgb_315.png to frame_00315.png
# Copied and renamed and adjusted brightnessrgb_860.png to frame_00860.png
# Copied and renamed and adjusted brightnessrgb_220.png to frame_00220.png
# Copied and renamed and adjusted brightnessrgb_16.png to frame_00016.png
# Copied and renamed and adjusted brightnessrgb_332.png to frame_00332.png
# Copied and renamed and adjusted brightnessrgb_288.png to frame_00288.png
# Copied and renamed and adjusted brightnessrgb_80.png to frame_00080.png
# Copied and renamed and adjusted brightnessrgb_697.png to frame_00697.png
# Copied and renamed and adjusted brightnessrgb_606.png to frame_00606.png
# Copied and renamed and adjusted brightnessrgb_257.png to frame_00257.png
# Copied and renamed and adjusted brightnessrgb_660.png to frame_00660.png
# Copied and renamed and adjusted brightnessrgb_883.png to frame_00883.png
# Copied and renamed and adjusted brightnessrgb_20.png to frame_00020.png
# Copied and renamed and adjusted brightnessrgb_379.png to frame_00379.png
# Copied and renamed and adjusted brightnessrgb_87.png to frame_00087.png
# Copied and renamed and adjusted brightnessrgb_712.png to frame_00712.png
# Copied and renamed and adjusted brightnessrgb_506.png to frame_00506.png
# Copied and renamed and adjusted brightnessrgb_386.png to frame_00386.png
# Copied and renamed and adjusted brightnessrgb_52.png to frame_00052.png
# Copied and renamed and adjusted brightnessrgb_566.png to frame_00566.png
# Copied and renamed and adjusted brightnessrgb_499.png to frame_00499.png
# Copied and renamed and adjusted brightnessrgb_428.png to frame_00428.png
# Copied and renamed and adjusted brightnessrgb_275.png to frame_00275.png
# Copied and renamed and adjusted brightnessrgb_121.png to frame_00121.png
# Copied and renamed and adjusted brightnessrgb_147.png to frame_00147.png
# Copied and renamed and adjusted brightnessrgb_830.png to frame_00830.png
# Copied and renamed and adjusted brightnessrgb_246.png to frame_00246.png
# Copied and renamed and adjusted brightnessrgb_42.png to frame_00042.png
# Copied and renamed and adjusted brightnessrgb_241.png to frame_00241.png
# Copied and renamed and adjusted brightnessrgb_825.png to frame_00825.png
# Copied and renamed and adjusted brightnessrgb_369.png to frame_00369.png
# Copied and renamed and adjusted brightnessrgb_171.png to frame_00171.png
# Copied and renamed and adjusted brightnessrgb_261.png to frame_00261.png
# Copied and renamed and adjusted brightnessrgb_630.png to frame_00630.png
# Copied and renamed and adjusted brightnessrgb_339.png to frame_00339.png
# Copied and renamed and adjusted brightnessrgb_408.png to frame_00408.png
# Copied and renamed and adjusted brightnessrgb_871.png to frame_00871.png
# Copied and renamed and adjusted brightnessrgb_477.png to frame_00477.png
# Copied and renamed and adjusted brightnessrgb_895.png to frame_00895.png
# Copied and renamed and adjusted brightnessrgb_322.png to frame_00322.png
# Copied and renamed and adjusted brightnessrgb_502.png to frame_00502.png
# Copied and renamed and adjusted brightnessrgb_896.png to frame_00896.png
# Copied and renamed and adjusted brightnessrgb_352.png to frame_00352.png
# Copied and renamed and adjusted brightnessrgb_552.png to frame_00552.png
# Copied and renamed and adjusted brightnessrgb_882.png to frame_00882.png
# Copied and renamed and adjusted brightnessrgb_687.png to frame_00687.png
# Copied and renamed and adjusted brightnessrgb_47.png to frame_00047.png
# Copied and renamed and adjusted brightnessrgb_113.png to frame_00113.png
# Copied and renamed and adjusted brightnessrgb_569.png to frame_00569.png
# Copied and renamed and adjusted brightnessrgb_643.png to frame_00643.png
# Copied and renamed and adjusted brightnessrgb_759.png to frame_00759.png
# Copied and renamed and adjusted brightnessrgb_438.png to frame_00438.png
# Copied and renamed and adjusted brightnessrgb_848.png to frame_00848.png
# Copied and renamed and adjusted brightnessrgb_780.png to frame_00780.png
# Copied and renamed and adjusted brightnessrgb_847.png to frame_00847.png
# Copied and renamed and adjusted brightnessrgb_305.png to frame_00305.png
# Copied and renamed and adjusted brightnessrgb_770.png to frame_00770.png
# Copied and renamed and adjusted brightnessrgb_693.png to frame_00693.png
# Copied and renamed and adjusted brightnessrgb_686.png to frame_00686.png
# Copied and renamed and adjusted brightnessrgb_636.png to frame_00636.png
# Copied and renamed and adjusted brightnessrgb_130.png to frame_00130.png
# Copied and renamed and adjusted brightnessrgb_542.png to frame_00542.png
# Copied and renamed and adjusted brightnessrgb_348.png to frame_00348.png
# Copied and renamed and adjusted brightnessrgb_586.png to frame_00586.png
# Copied and renamed and adjusted brightnessrgb_304.png to frame_00304.png
# Copied and renamed and adjusted brightnessrgb_835.png to frame_00835.png
# Copied and renamed and adjusted brightnessrgb_294.png to frame_00294.png
# Copied and renamed and adjusted brightnessrgb_881.png to frame_00881.png
# Copied and renamed and adjusted brightnessrgb_81.png to frame_00081.png
# Copied and renamed and adjusted brightnessrgb_57.png to frame_00057.png
# Copied and renamed and adjusted brightnessrgb_329.png to frame_00329.png
# Copied and renamed and adjusted brightnessrgb_596.png to frame_00596.png
# Copied and renamed and adjusted brightnessrgb_195.png to frame_00195.png
# Copied and renamed and adjusted brightnessrgb_876.png to frame_00876.png
# Copied and renamed and adjusted brightnessrgb_700.png to frame_00700.png
# Copied and renamed and adjusted brightnessrgb_445.png to frame_00445.png
# Copied and renamed and adjusted brightnessrgb_53.png to frame_00053.png
# Copied and renamed and adjusted brightnessrgb_624.png to frame_00624.png
# Copied and renamed and adjusted brightnessrgb_602.png to frame_00602.png
# Copied and renamed and adjusted brightnessrgb_724.png to frame_00724.png
# Copied and renamed and adjusted brightnessrgb_429.png to frame_00429.png
# Copied and renamed and adjusted brightnessrgb_44.png to frame_00044.png
# Copied and renamed and adjusted brightnessrgb_771.png to frame_00771.png
# Copied and renamed and adjusted brightnessrgb_206.png to frame_00206.png
# Copied and renamed and adjusted brightnessrgb_613.png to frame_00613.png
# Copied and renamed and adjusted brightnessrgb_167.png to frame_00167.png
# Copied and renamed and adjusted brightnessrgb_374.png to frame_00374.png
# Copied and renamed and adjusted brightnessrgb_548.png to frame_00548.png
# Copied and renamed and adjusted brightnessrgb_77.png to frame_00077.png
# Copied and renamed and adjusted brightnessrgb_710.png to frame_00710.png
# Copied and renamed and adjusted brightnessrgb_716.png to frame_00716.png
# Copied and renamed and adjusted brightnessrgb_146.png to frame_00146.png
# Copied and renamed and adjusted brightnessrgb_67.png to frame_00067.png
# Copied and renamed and adjusted brightnessrgb_323.png to frame_00323.png
# Copied and renamed and adjusted brightnessrgb_197.png to frame_00197.png
# Copied and renamed and adjusted brightnessrgb_91.png to frame_00091.png
# Copied and renamed and adjusted brightnessrgb_129.png to frame_00129.png
# Copied and renamed and adjusted brightnessrgb_639.png to frame_00639.png
# Copied and renamed and adjusted brightnessrgb_575.png to frame_00575.png
# Copied and renamed and adjusted brightnessrgb_225.png to frame_00225.png
# Copied and renamed and adjusted brightnessrgb_430.png to frame_00430.png
# Copied and renamed and adjusted brightnessrgb_411.png to frame_00411.png
# Copied and renamed and adjusted brightnessrgb_898.png to frame_00898.png
# Copied and renamed and adjusted brightnessrgb_21.png to frame_00021.png
# Copied and renamed and adjusted brightnessrgb_465.png to frame_00465.png
# Copied and renamed and adjusted brightnessrgb_479.png to frame_00479.png
# Copied and renamed and adjusted brightnessrgb_98.png to frame_00098.png
# Copied and renamed and adjusted brightnessrgb_282.png to frame_00282.png
# Copied and renamed and adjusted brightnessrgb_76.png to frame_00076.png
# Copied and renamed and adjusted brightnessrgb_509.png to frame_00509.png
# Copied and renamed and adjusted brightnessrgb_619.png to frame_00619.png
# Copied and renamed and adjusted brightnessrgb_762.png to frame_00762.png
# Copied and renamed and adjusted brightnessrgb_446.png to frame_00446.png
# Copied and renamed and adjusted brightnessrgb_380.png to frame_00380.png
# Copied and renamed and adjusted brightnessrgb_425.png to frame_00425.png
# Copied and renamed and adjusted brightnessrgb_609.png to frame_00609.png
# Copied and renamed and adjusted brightnessrgb_390.png to frame_00390.png
# Copied and renamed and adjusted brightnessrgb_588.png to frame_00588.png
# Copied and renamed and adjusted brightnessrgb_421.png to frame_00421.png
# Copied and renamed and adjusted brightnessrgb_816.png to frame_00816.png
# Copied and renamed and adjusted brightnessrgb_649.png to frame_00649.png
# Copied and renamed and adjusted brightnessrgb_474.png to frame_00474.png
# Copied and renamed and adjusted brightnessrgb_404.png to frame_00404.png
# Copied and renamed and adjusted brightnessrgb_514.png to frame_00514.png
# Copied and renamed and adjusted brightnessrgb_324.png to frame_00324.png
# Copied and renamed and adjusted brightnessrgb_766.png to frame_00766.png
# Copied and renamed and adjusted brightnessrgb_267.png to frame_00267.png
# Copied and renamed and adjusted brightnessrgb_884.png to frame_00884.png
# Copied and renamed and adjusted brightnessrgb_783.png to frame_00783.png
# Copied and renamed and adjusted brightnessrgb_29.png to frame_00029.png
# Copied and renamed and adjusted brightnessrgb_375.png to frame_00375.png
# Copied and renamed and adjusted brightnessrgb_604.png to frame_00604.png
# Copied and renamed and adjusted brightnessrgb_435.png to frame_00435.png
# Copied and renamed and adjusted brightnessrgb_812.png to frame_00812.png
# Copied and renamed and adjusted brightnessrgb_367.png to frame_00367.png
# Copied and renamed and adjusted brightnessrgb_30.png to frame_00030.png
# Copied and renamed and adjusted brightnessrgb_666.png to frame_00666.png
# Copied and renamed and adjusted brightnessrgb_582.png to frame_00582.png
# Copied and renamed and adjusted brightnessrgb_96.png to frame_00096.png
# Copied and renamed and adjusted brightnessrgb_344.png to frame_00344.png
# Copied and renamed and adjusted brightnessrgb_732.png to frame_00732.png
# Copied and renamed and adjusted brightnessrgb_823.png to frame_00823.png
# Copied and renamed and adjusted brightnessrgb_642.png to frame_00642.png
# Copied and renamed and adjusted brightnessrgb_131.png to frame_00131.png
# Copied and renamed and adjusted brightnessrgb_488.png to frame_00488.png
# Copied and renamed and adjusted brightnessrgb_534.png to frame_00534.png
# Copied and renamed and adjusted brightnessrgb_735.png to frame_00735.png
# Copied and renamed and adjusted brightnessrgb_893.png to frame_00893.png
# Copied and renamed and adjusted brightnessrgb_3.png to frame_00003.png
# Copied and renamed and adjusted brightnessrgb_621.png to frame_00621.png
# Copied and renamed and adjusted brightnessrgb_560.png to frame_00560.png
# Copied and renamed and adjusted brightnessrgb_705.png to frame_00705.png
# Copied and renamed and adjusted brightnessrgb_100.png to frame_00100.png
# Copied and renamed and adjusted brightnessrgb_226.png to frame_00226.png
# Copied and renamed and adjusted brightnessrgb_199.png to frame_00199.png
# Copied and renamed and adjusted brightnessrgb_581.png to frame_00581.png
# Copied and renamed and adjusted brightnessrgb_553.png to frame_00553.png
# Copied and renamed and adjusted brightnessrgb_245.png to frame_00245.png
# Copied and renamed and adjusted brightnessrgb_782.png to frame_00782.png
# Copied and renamed and adjusted brightnessrgb_817.png to frame_00817.png
# Copied and renamed and adjusted brightnessrgb_584.png to frame_00584.png
# Copied and renamed and adjusted brightnessrgb_790.png to frame_00790.png
# Copied and renamed and adjusted brightnessrgb_43.png to frame_00043.png
# Copied and renamed and adjusted brightnessrgb_629.png to frame_00629.png
# Copied and renamed and adjusted brightnessrgb_125.png to frame_00125.png
# Copied and renamed and adjusted brightnessrgb_658.png to frame_00658.png
# Copied and renamed and adjusted brightnessrgb_472.png to frame_00472.png
# Copied and renamed and adjusted brightnessrgb_875.png to frame_00875.png
# Copied and renamed and adjusted brightnessrgb_507.png to frame_00507.png
# Copied and renamed and adjusted brightnessrgb_557.png to frame_00557.png
# Copied and renamed and adjusted brightnessrgb_148.png to frame_00148.png
# Copied and renamed and adjusted brightnessrgb_689.png to frame_00689.png
# Copied and renamed and adjusted brightnessrgb_144.png to frame_00144.png
# Copied and renamed and adjusted brightnessrgb_360.png to frame_00360.png
# Copied and renamed and adjusted brightnessrgb_231.png to frame_00231.png
# Copied and renamed and adjusted brightnessrgb_28.png to frame_00028.png
# Copied and renamed and adjusted brightnessrgb_2.png to frame_00002.png
# Copied and renamed and adjusted brightnessrgb_150.png to frame_00150.png
# Copied and renamed and adjusted brightnessrgb_142.png to frame_00142.png
# Copied and renamed and adjusted brightnessrgb_683.png to frame_00683.png
# Copied and renamed and adjusted brightnessrgb_698.png to frame_00698.png
# Copied and renamed and adjusted brightnessrgb_708.png to frame_00708.png
# Copied and renamed and adjusted brightnessrgb_128.png to frame_00128.png
# Copied and renamed and adjusted brightnessrgb_253.png to frame_00253.png
# Copied and renamed and adjusted brightnessrgb_819.png to frame_00819.png
# Copied and renamed and adjusted brightnessrgb_140.png to frame_00140.png
# Copied and renamed and adjusted brightnessrgb_45.png to frame_00045.png
# Copied and renamed and adjusted brightnessrgb_351.png to frame_00351.png
# Copied and renamed and adjusted brightnessrgb_23.png to frame_00023.png
# Copied and renamed and adjusted brightnessrgb_163.png to frame_00163.png
# Copied and renamed and adjusted brightnessrgb_161.png to frame_00161.png
# Copied and renamed and adjusted brightnessrgb_715.png to frame_00715.png
# Copied and renamed and adjusted brightnessrgb_486.png to frame_00486.png
# Copied and renamed and adjusted brightnessrgb_563.png to frame_00563.png
# Copied and renamed and adjusted brightnessrgb_189.png to frame_00189.png
# Copied and renamed and adjusted brightnessrgb_103.png to frame_00103.png
# Copied and renamed and adjusted brightnessrgb_493.png to frame_00493.png
# Copied and renamed and adjusted brightnessrgb_789.png to frame_00789.png
# Copied and renamed and adjusted brightnessrgb_392.png to frame_00392.png
# Copied and renamed and adjusted brightnessrgb_489.png to frame_00489.png
# Copied and renamed and adjusted brightnessrgb_556.png to frame_00556.png
# Copied and renamed and adjusted brightnessrgb_752.png to frame_00752.png
# Copied and renamed and adjusted brightnessrgb_829.png to frame_00829.png
# Copied and renamed and adjusted brightnessrgb_870.png to frame_00870.png
# Copied and renamed and adjusted brightnessrgb_498.png to frame_00498.png
# Copied and renamed and adjusted brightnessrgb_134.png to frame_00134.png
# Copied and renamed and adjusted brightnessrgb_611.png to frame_00611.png
# Copied and renamed and adjusted brightnessrgb_286.png to frame_00286.png
# Copied and renamed and adjusted brightnessrgb_75.png to frame_00075.png
# Copied and renamed and adjusted brightnessrgb_154.png to frame_00154.png
# Copied and renamed and adjusted brightnessrgb_252.png to frame_00252.png
# Copied and renamed and adjusted brightnessrgb_785.png to frame_00785.png
# Copied and renamed and adjusted brightnessrgb_779.png to frame_00779.png
# Copied and renamed and adjusted brightnessrgb_571.png to frame_00571.png
# Copied and renamed and adjusted brightnessrgb_713.png to frame_00713.png
# Copied and renamed and adjusted brightnessrgb_727.png to frame_00727.png
# Copied and renamed and adjusted brightnessrgb_473.png to frame_00473.png
# Copied and renamed and adjusted brightnessrgb_306.png to frame_00306.png
# Copied and renamed and adjusted brightnessrgb_897.png to frame_00897.png
# Copied and renamed and adjusted brightnessrgb_165.png to frame_00165.png
# Copied and renamed and adjusted brightnessrgb_688.png to frame_00688.png
# Copied and renamed and adjusted brightnessrgb_627.png to frame_00627.png
# Copied and renamed and adjusted brightnessrgb_308.png to frame_00308.png
# Copied and renamed and adjusted brightnessrgb_457.png to frame_00457.png
# Copied and renamed and adjusted brightnessrgb_818.png to frame_00818.png
# Copied and renamed and adjusted brightnessrgb_270.png to frame_00270.png
# Copied and renamed and adjusted brightnessrgb_64.png to frame_00064.png
# Copied and renamed and adjusted brightnessrgb_152.png to frame_00152.png
# Copied and renamed and adjusted brightnessrgb_487.png to frame_00487.png
# Copied and renamed and adjusted brightnessrgb_626.png to frame_00626.png
# Copied and renamed and adjusted brightnessrgb_644.png to frame_00644.png
# Copied and renamed and adjusted brightnessrgb_307.png to frame_00307.png
# Copied and renamed and adjusted brightnessrgb_377.png to frame_00377.png
# Copied and renamed and adjusted brightnessrgb_615.png to frame_00615.png
# Copied and renamed and adjusted brightnessrgb_285.png to frame_00285.png
# Copied and renamed and adjusted brightnessrgb_296.png to frame_00296.png
# Copied and renamed and adjusted brightnessrgb_508.png to frame_00508.png
# Copied and renamed and adjusted brightnessrgb_747.png to frame_00747.png
# Copied and renamed and adjusted brightnessrgb_872.png to frame_00872.png
# Copied and renamed and adjusted brightnessrgb_357.png to frame_00357.png
# Copied and renamed and adjusted brightnessrgb_774.png to frame_00774.png
# Copied and renamed and adjusted brightnessrgb_885.png to frame_00885.png
# Copied and renamed and adjusted brightnessrgb_675.png to frame_00675.png
# Copied and renamed and adjusted brightnessrgb_723.png to frame_00723.png
# Copied and renamed and adjusted brightnessrgb_93.png to frame_00093.png
# Copied and renamed and adjusted brightnessrgb_92.png to frame_00092.png
# Copied and renamed and adjusted brightnessrgb_605.png to frame_00605.png
# ...
# Copied and renamed and adjusted brightnessrgb_314.png to frame_00314.png
# Copied and renamed and adjusted brightnessrgb_70.png to frame_00070.png
# Copied and renamed and adjusted brightnessrgb_661.png to frame_00661.png
# Copied and renamed and adjusted brightnessrgb_481.png to frame_00481.png
# Copied and renamed and adjusted brightnessrgb_454.png to frame_00454.png
# Copied and renamed and adjusted brightnessrgb_181.png to frame_00181.png
# Copied and renamed and adjusted brightnessrgb_102.png to frame_00102.png
# Copied and renamed and adjusted brightnessrgb_857.png to frame_00857.png
# Copied and renamed and adjusted brightnessrgb_589.png to frame_00589.png
# Copied and renamed and adjusted brightnessrgb_27.png to frame_00027.png
# Copied and renamed and adjusted brightnessrgb_838.png to frame_00838.png
# Copied and renamed and adjusted brightnessrgb_262.png to frame_00262.png
# Copied and renamed and adjusted brightnessrgb_799.png to frame_00799.png
# Copied and renamed and adjusted brightnessrgb_55.png to frame_00055.png
# Copied and renamed and adjusted brightnessrgb_183.png to frame_00183.png
# Copied and renamed and adjusted brightnessrgb_327.png to frame_00327.png
# Copied and renamed and adjusted brightnessrgb_832.png to frame_00832.png
# Copied and renamed and adjusted brightnessrgb_691.png to frame_00691.png
# Copied and renamed and adjusted brightnessrgb_889.png to frame_00889.png
# Copied and renamed and adjusted brightnessrgb_320.png to frame_00320.png
# Copied and renamed and adjusted brightnessrgb_496.png to frame_00496.png
# Copied and renamed and adjusted brightnessrgb_720.png to frame_00720.png
# Copied and renamed and adjusted brightnessrgb_108.png to frame_00108.png
# Copied and renamed and adjusted brightnessrgb_531.png to frame_00531.png
# Copied and renamed and adjusted brightnessrgb_65.png to frame_00065.png
# Copied and renamed and adjusted brightnessrgb_467.png to frame_00467.png
# Copied and renamed and adjusted brightnessrgb_684.png to frame_00684.png
# Copied and renamed and adjusted brightnessrgb_120.png to frame_00120.png
# Copied and renamed and adjusted brightnessrgb_809.png to frame_00809.png
# Copied and renamed and adjusted brightnessrgb_772.png to frame_00772.png
# Copied and renamed and adjusted brightnessrgb_176.png to frame_00176.png
# Copied and renamed and adjusted brightnessrgb_763.png to frame_00763.png
# Copied and renamed and adjusted brightnessrgb_361.png to frame_00361.png
# Copied and renamed and adjusted brightnessrgb_312.png to frame_00312.png
# Copied and renamed and adjusted brightnessrgb_787.png to frame_00787.png
# Copied and renamed and adjusted brightnessrgb_89.png to frame_00089.png
# Copied and renamed and adjusted brightnessrgb_637.png to frame_00637.png
# Copied and renamed and adjusted brightnessrgb_475.png to frame_00475.png
# Copied and renamed and adjusted brightnessrgb_617.png to frame_00617.png
# Copied and renamed and adjusted brightnessrgb_544.png to frame_00544.png
# Copied and renamed and adjusted brightnessrgb_804.png to frame_00804.png
# Copied and renamed and adjusted brightnessrgb_188.png to frame_00188.png
# Copied and renamed and adjusted brightnessrgb_280.png to frame_00280.png
# Copied and renamed and adjusted brightnessrgb_97.png to frame_00097.png
# Copied and renamed and adjusted brightnessrgb_105.png to frame_00105.png
# Copied and renamed and adjusted brightnessrgb_505.png to frame_00505.png
# Copied and renamed and adjusted brightnessrgb_291.png to frame_00291.png
# Copied and renamed and adjusted brightnessrgb_833.png to frame_00833.png
# Copied and renamed and adjusted brightnessrgb_330.png to frame_00330.png
# Copied and renamed and adjusted brightnessrgb_420.png to frame_00420.png
# Copied and renamed and adjusted brightnessrgb_399.png to frame_00399.png
# Copied and renamed and adjusted brightnessrgb_145.png to frame_00145.png
# Copied and renamed and adjusted brightnessrgb_864.png to frame_00864.png
# Copied and renamed and adjusted brightnessrgb_565.png to frame_00565.png
# Copied and renamed and adjusted brightnessrgb_593.png to frame_00593.png
# Copied and renamed and adjusted brightnessrgb_272.png to frame_00272.png
# Copied and renamed and adjusted brightnessrgb_106.png to frame_00106.png
# Copied and renamed and adjusted brightnessrgb_524.png to frame_00524.png
# Copied and renamed and adjusted brightnessrgb_186.png to frame_00186.png
# Copied and renamed and adjusted brightnessrgb_8.png to frame_00008.png
# Copied and renamed and adjusted brightnessrgb_1.png to frame_00001.png
# Copied and renamed and adjusted brightnessrgb_107.png to frame_00107.png
# Copied and renamed and adjusted brightnessrgb_899.png to frame_00899.png
# Copied and renamed and adjusted brightnessrgb_841.png to frame_00841.png
# Copied and renamed and adjusted brightnessrgb_368.png to frame_00368.png
# Copied and renamed and adjusted brightnessrgb_366.png to frame_00366.png
# Copied and renamed and adjusted brightnessrgb_243.png to frame_00243.png
# Copied and renamed and adjusted brightnessrgb_767.png to frame_00767.png
# Copied and renamed and adjusted brightnessrgb_664.png to frame_00664.png
# Copied and renamed and adjusted brightnessrgb_497.png to frame_00497.png
# Copied and renamed and adjusted brightnessrgb_656.png to frame_00656.png
# Copied and renamed and adjusted brightnessrgb_464.png to frame_00464.png
# Copied and renamed and adjusted brightnessrgb_749.png to frame_00749.png
# Copied and renamed and adjusted brightnessrgb_721.png to frame_00721.png
# Copied and renamed and adjusted brightnessrgb_412.png to frame_00412.png
# Copied and renamed and adjusted brightnessrgb_452.png to frame_00452.png
# Copied and renamed and adjusted brightnessrgb_300.png to frame_00300.png
# Copied and renamed and adjusted brightnessrgb_185.png to frame_00185.png
# Copied and renamed and adjusted brightnessrgb_549.png to frame_00549.png
# Copied and renamed and adjusted brightnessrgb_453.png to frame_00453.png
# Copied and renamed and adjusted brightnessrgb_137.png to frame_00137.png
# Copied and renamed and adjusted brightnessrgb_247.png to frame_00247.png
# Copied and renamed and adjusted brightnessrgb_466.png to frame_00466.png
# Copied and renamed and adjusted brightnessrgb_806.png to frame_00806.png
# Copied and renamed and adjusted brightnessrgb_775.png to frame_00775.png
# Copied and renamed and adjusted brightnessrgb_123.png to frame_00123.png
# Copied and renamed and adjusted brightnessrgb_388.png to frame_00388.png
# Copied and renamed and adjusted brightnessrgb_326.png to frame_00326.png
# Copied and renamed and adjusted brightnessrgb_672.png to frame_00672.png
# Copied and renamed and adjusted brightnessrgb_655.png to frame_00655.png
# Copied and renamed and adjusted brightnessrgb_810.png to frame_00810.png
# Copied and renamed and adjusted brightnessrgb_41.png to frame_00041.png
# Copied and renamed and adjusted brightnessrgb_826.png to frame_00826.png
# Copied and renamed and adjusted brightnessrgb_289.png to frame_00289.png
# Copied and renamed and adjusted brightnessrgb_888.png to frame_00888.png
# Copied and renamed and adjusted brightnessrgb_393.png to frame_00393.png
# Copied and renamed and adjusted brightnessrgb_51.png to frame_00051.png
# Copied and renamed and adjusted brightnessrgb_521.png to frame_00521.png
# Copied and renamed and adjusted brightnessrgb_177.png to frame_00177.png
# Copied and renamed and adjusted brightnessrgb_182.png to frame_00182.png
# Copied and renamed and adjusted brightnessrgb_119.png to frame_00119.png
# Copied and renamed and adjusted brightnessrgb_336.png to frame_00336.png
# Copied and renamed and adjusted brightnessrgb_413.png to frame_00413.png
# Copied and renamed and adjusted brightnessrgb_849.png to frame_00849.png
# Copied and renamed and adjusted brightnessrgb_284.png to frame_00284.png
# Copied and renamed and adjusted brightnessrgb_215.png to frame_00215.png
# Copied and renamed and adjusted brightnessrgb_866.png to frame_00866.png
# Copied and renamed and adjusted brightnessrgb_462.png to frame_00462.png
# Copied and renamed and adjusted brightnessrgb_741.png to frame_00741.png
# Copied and renamed and adjusted brightnessrgb_338.png to frame_00338.png
# Copied and renamed and adjusted brightnessrgb_458.png to frame_00458.png
# Copied and renamed and adjusted brightnessrgb_184.png to frame_00184.png
# Copied and renamed and adjusted brightnessrgb_801.png to frame_00801.png
# Copied and renamed and adjusted brightnessrgb_851.png to frame_00851.png
# Copied and renamed and adjusted brightnessrgb_685.png to frame_00685.png
# Copied and renamed and adjusted brightnessrgb_501.png to frame_00501.png
# Copied and renamed and adjusted brightnessrgb_551.png to frame_00551.png
# Copied and renamed and adjusted brightnessrgb_836.png to frame_00836.png
# Copied and renamed and adjusted brightnessrgb_372.png to frame_00372.png
# Copied and renamed and adjusted brightnessrgb_373.png to frame_00373.png
# Copied and renamed and adjusted brightnessrgb_155.png to frame_00155.png
# Copied and renamed and adjusted brightnessrgb_750.png to frame_00750.png
# Copied and renamed and adjusted brightnessrgb_168.png to frame_00168.png
# Copied and renamed and adjusted brightnessrgb_676.png to frame_00676.png
# Copied and renamed and adjusted brightnessrgb_60.png to frame_00060.png
# Copied and renamed and adjusted brightnessrgb_612.png to frame_00612.png
# Copied and renamed and adjusted brightnessrgb_834.png to frame_00834.png
# Copied and renamed and adjusted brightnessrgb_448.png to frame_00448.png
# Copied and renamed and adjusted brightnessrgb_468.png to frame_00468.png
# Copied and renamed and adjusted brightnessrgb_363.png to frame_00363.png
# Copied and renamed and adjusted brightnessrgb_718.png to frame_00718.png
# Copied and renamed and adjusted brightnessrgb_699.png to frame_00699.png
# Copied and renamed and adjusted brightnessrgb_574.png to frame_00574.png
# Copied and renamed and adjusted brightnessrgb_680.png to frame_00680.png
# Copied and renamed and adjusted brightnessrgb_292.png to frame_00292.png
# Copied and renamed and adjusted brightnessrgb_824.png to frame_00824.png
# Copied and renamed and adjusted brightnessrgb_635.png to frame_00635.png
# Copied and renamed and adjusted brightnessrgb_407.png to frame_00407.png
# Copied and renamed and adjusted brightnessrgb_22.png to frame_00022.png
# Copied and renamed and adjusted brightnessrgb_18.png to frame_00018.png
# Copied and renamed and adjusted brightnessrgb_341.png to frame_00341.png
# Copied and renamed and adjusted brightnessrgb_209.png to frame_00209.png
# Copied and renamed and adjusted brightnessrgb_633.png to frame_00633.png
# Copied and renamed and adjusted brightnessrgb_233.png to frame_00233.png
# Copied and renamed and adjusted brightnessrgb_90.png to frame_00090.png
# Copied and renamed and adjusted brightnessrgb_791.png to frame_00791.png
# Copied and renamed and adjusted brightnessrgb_5.png to frame_00005.png
# Copied and renamed and adjusted brightnessrgb_846.png to frame_00846.png
# Copied and renamed and adjusted brightnessrgb_385.png to frame_00385.png
# Copied and renamed and adjusted brightnessrgb_71.png to frame_00071.png
# Copied and renamed and adjusted brightnessrgb_156.png to frame_00156.png
# Copied and renamed and adjusted brightnessrgb_743.png to frame_00743.png
# Copied and renamed and adjusted brightnessrgb_597.png to frame_00597.png
# Copied and renamed and adjusted brightnessrgb_891.png to frame_00891.png
# Copied and renamed and adjusted brightnessrgb_7.png to frame_00007.png
# Copied and renamed and adjusted brightnessrgb_436.png to frame_00436.png
# Copied and renamed and adjusted brightnessrgb_201.png to frame_00201.png
# Copied and renamed and adjusted brightnessrgb_483.png to frame_00483.png
# Copied and renamed and adjusted brightnessrgb_4.png to frame_00004.png
# Copied and renamed and adjusted brightnessrgb_757.png to frame_00757.png
# Copied and renamed and adjusted brightnessrgb_739.png to frame_00739.png
# Copied and renamed and adjusted brightnessrgb_576.png to frame_00576.png
# Copied and renamed and adjusted brightnessrgb_311.png to frame_00311.png
# Copied and renamed and adjusted brightnessrgb_175.png to frame_00175.png
# Copied and renamed and adjusted brightnessrgb_856.png to frame_00856.png
# Copied and renamed and adjusted brightnessrgb_198.png to frame_00198.png
# Copied and renamed and adjusted brightnessrgb_24.png to frame_00024.png
# Copied and renamed and adjusted brightnessrgb_755.png to frame_00755.png
# Copied and renamed and adjusted brightnessrgb_256.png to frame_00256.png
# Copied and renamed and adjusted brightnessrgb_742.png to frame_00742.png
# Copied and renamed and adjusted brightnessrgb_0.png to frame_00000.png
# Copied and renamed and adjusted brightnessrgb_805.png to frame_00805.png
# Copied and renamed and adjusted brightnessrgb_707.png to frame_00707.png
# Copied and renamed and adjusted brightnessrgb_669.png to frame_00669.png
# Copied and renamed and adjusted brightnessrgb_773.png to frame_00773.png
# Copied and renamed and adjusted brightnessrgb_736.png to frame_00736.png
# Copied and renamed and adjusted brightnessrgb_394.png to frame_00394.png
# Copied and renamed and adjusted brightnessrgb_418.png to frame_00418.png
# Copied and renamed and adjusted brightnessrgb_594.png to frame_00594.png
# Copied and renamed and adjusted brightnessrgb_281.png to frame_00281.png
# Copied and renamed and adjusted brightnessrgb_36.png to frame_00036.png
# Copied and renamed and adjusted brightnessrgb_316.png to frame_00316.png
# Copied and renamed and adjusted brightnessrgb_603.png to frame_00603.png
# Copied and renamed and adjusted brightnessrgb_567.png to frame_00567.png
# Copied and renamed and adjusted brightnessrgb_821.png to frame_00821.png
# Copied and renamed and adjusted brightnessrgb_598.png to frame_00598.png
# Copied and renamed and adjusted brightnessrgb_730.png to frame_00730.png
# Copied and renamed and adjusted brightnessrgb_151.png to frame_00151.png
# Copied and renamed and adjusted brightnessrgb_15.png to frame_00015.png
# Copied and renamed and adjusted brightnessrgb_795.png to frame_00795.png
# Copied and renamed and adjusted brightnessrgb_640.png to frame_00640.png
# Copied and renamed and adjusted brightnessrgb_814.png to frame_00814.png
# Copied and renamed and adjusted brightnessrgb_135.png to frame_00135.png
# Copied and renamed and adjusted brightnessrgb_346.png to frame_00346.png
# Copied and renamed and adjusted brightnessrgb_650.png to frame_00650.png
# Copied and renamed and adjusted brightnessrgb_381.png to frame_00381.png
# Copied and renamed and adjusted brightnessrgb_696.png to frame_00696.png
# Copied and renamed and adjusted brightnessrgb_389.png to frame_00389.png
# Copied and renamed and adjusted brightnessrgb_33.png to frame_00033.png
# Copied and renamed and adjusted brightnessrgb_874.png to frame_00874.png
# Copied and renamed and adjusted brightnessrgb_719.png to frame_00719.png
# Copied and renamed and adjusted brightnessrgb_383.png to frame_00383.png
# Copied and renamed and adjusted brightnessrgb_299.png to frame_00299.png
# Copied and renamed and adjusted brightnessrgb_391.png to frame_00391.png
# Copied and renamed and adjusted brightnessrgb_279.png to frame_00279.png
# Copied and renamed and adjusted brightnessrgb_657.png to frame_00657.png
# Copied and renamed and adjusted brightnessrgb_359.png to frame_00359.png
# Copied and renamed and adjusted brightnessrgb_84.png to frame_00084.png
# Copied and renamed and adjusted brightnessrgb_776.png to frame_00776.png
# Copied and renamed and adjusted brightnessrgb_400.png to frame_00400.png
# Copied and renamed and adjusted brightnessrgb_820.png to frame_00820.png
# Copied and renamed and adjusted brightnessrgb_274.png to frame_00274.png
# Copied and renamed and adjusted brightnessrgb_622.png to frame_00622.png
# Copied and renamed and adjusted brightnessrgb_317.png to frame_00317.png
# Copied and renamed and adjusted brightnessrgb_577.png to frame_00577.png
# Copied and renamed and adjusted brightnessrgb_19.png to frame_00019.png
# Copied and renamed and adjusted brightnessrgb_94.png to frame_00094.png
# Copied and renamed and adjusted brightnessrgb_886.png to frame_00886.png
# Copied and renamed and adjusted brightnessrgb_728.png to frame_00728.png
